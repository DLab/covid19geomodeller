# %% [markdown]
# # SEIR model example
# \begin{align}
# \dot{S} & = S_f - \alpha\beta\frac{SI}{N+k_I I+k_R R} + r_{R\_S} R\\
# \dot{E} & = E_f + \alpha\beta\frac{SI}{N+k_I I+k_R R} - E\frac{1}{t_{E\_I}} \\
# \dot{I} & = I_f + E\frac{1}{t_{E\_I}} - I\frac{1}{t_{I\_R}} \\
# \dot{R} & = R_f + I\frac{1}{t_{I\_R}} - r_{I\_R} R\\
# \end{align}
# Where:
# * $S:$ Susceptible
# * $E:$ Exposed
# * $I:$ Infectious
# * $R:$ Removed
# * $\alpha:$ Mobilty
# * $\beta:$ Infection rate
# * $N:$ Total population
# * $t_{E\_I}:$ # Transition time between exposed and infectious
# * $t_{I\_R}:$ # Transition time between infectious and recovered
# * $r_{R\_S}:$ Immunity loss rate ($\frac{1}{t_{R\_S}}$)
# * $S_f,E_f,I_f,R_f:$ External flux
# * $k_I:$ Infected saturation
# * $k_R:$ Immunity shield

# %%
# Util libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
# Adding lib paths
import sys
sys.path.insert(1, '../src2/models/')

# cv19 libraries
from SEIR import SEIR

#sys.path.insert(1, '../src2/data/')
#sys.path.insert(1, '../src2/utils/')
#import cv19functions
#import cv19data

# %%
# For pop-up plots execute this code (optional)
import platform
OS = platform.system()

if OS == 'Linux':    
    # %matplotlib tk
    print('Linux')
elif OS == 'Windows':
    # %matplotlib qt
    print('Windows')
elif OS == 'Darwin':
    # %matplotlib tk
    print('Mac (Funciona?)')
# Out:
# Linux

# %% [markdown]
# # Build a basic SEIR model using a configuration file

# %% [markdown]
# ## Constant parameters

# %%
# Input configuration file
config = 'cfg/SEIR.toml'

# %%
# Build simulation object
model = SEIR(config = config)
# Out:
# SEIR object created

# %%
# %%capture
# Simulate (solve ODE)
model.integrate()

# %%
# Show results
model.results
# Out:
#        t dates       S     E   E_d     I   I_d       R  R_d  Flux    E_ac  \
# 0      0  None  986000  3000  1500  6000  2999    5000    0   0.0    1500
# 1      1  None  984813  3531  1302  6052  1523    5601  380   0.0    2802
# 2      2  None  983609  3982  1241  6193  1040    6213  527   0.0    4043
# 3      3  None  982372  4382  1240  6401   916    6842  592   0.0    5284
# 4      4  None  981090  4750  1269  6662   918    7495  632   0.0    6553
# ..   ...   ...     ...   ...   ...   ...   ...     ...  ...   ...     ...
# 495  495  None  201828     0     0     0     0  798171    0   0.0  786444
# 496  496  None  201828     0     0     0     0  798171    0   0.0  786444
# 497  497  None  201828     0     0     0     0  798171    0   0.0  786444
# 498  498  None  201828     0     0     0     0  798171    0   0.0  786444
# 499  499  None  201828     0     0     0     0  798171    0   0.0  786444
#
#        I_ac    R_ac  I_det  I_d_det  I_ac_det  prevalence_total  \
# 0     18000       0   6000     2999     18000          0.018000
# 1     19523     380   6052     1523     19523          0.019523
# 2     20563     908   6193     1040     20563          0.020564
# 3     21479    1501   6401      916     21479          0.021480
# 4     22398    2133   6662      918     22398          0.022398
# ..      ...     ...    ...      ...       ...               ...
# 495  806823  793048      0        0    806823          0.806824
# 496  806823  793048      0        0    806823          0.806824
# 497  806823  793048      0        0    806823          0.806824
# 498  806823  793048      0        0    806823          0.806824
# 499  806823  793048      0        0    806823          0.806824
#
#      prevalence_susc  prevalence_det
# 0           0.018000        0.018000
# 1           0.019523        0.019523
# 2           0.020564        0.020564
# 3           0.021480        0.021480
# 4           0.022398        0.022398
# ..               ...             ...
# 495         0.806824        0.806824
# 496         0.806824        0.806824
# 497         0.806824        0.806824
# 498         0.806824        0.806824
# 499         0.806824        0.806824
#
# [500 rows x 19 columns]

# %%
# Plot matplotlib
plt.plot(model.t,model.S,label='S')
plt.plot(model.t,model.E,label='E')
plt.plot(model.t,model.I,label='I')
plt.plot(model.t,model.R,label='R')
plt.xlim(0,300)
plt.legend(loc=0)
plt.show()

# %%
# Plot with pandas
ax = model.results.plot(x='t',y=['S','E','I','R'])
ax.set_xlim(0,300)
ax.set_title('SEIR simulation plot')
# Out:
# Text(0.5, 1.0, 'SEIR simulation plot')

# %% [markdown]
# ## Variable parameters
# Create a function with time dependent parameters. Check covid19functions notebook for more information on this.

# %%
config2 = 'cfg/SEIR_v2.toml'

# %%
model2 = SEIR(config = config2)
# Out:
# Executing Events
# Executing Events
# No external data added
# SEIR object created

# %%
# %%capture
model2.integrate()

# %%
plt.plot(model2.t,model2.S,label='S')
plt.plot(model2.t,model2.E,label='E')
plt.plot(model2.t,model2.I,label='I')
plt.plot(model2.t,model2.R,label='R')
plt.xlim(0,300)
plt.legend(loc=0)
plt.show()
