# %% [markdown]
# # SEIRHVD Data Fit
#
# This Jupyter notebooks implements the SEIRHVD model for fitting the actual Chilean data in order to make projections in VMI and bed usage, amount of infected and deaths. This model uses the SEIRHVD 4.1 version. A visual representation of the model is available at: [SEIRHVD Miró Model](https://miro.com/app/board/o9J_ktzN4xA=/)
#
# This implements a single instance to facilitate understanding the model prior to run multiple data fittings at a time.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates 
from datetime import datetime
from numpy import linalg as LA
import multiprocessing
from joblib import Parallel, delayed
from datetime import timedelta

import platform
OS = platform.system()

import matplotlib.pyplot as plt
if OS == 'Linux':    
    # %matplotlib tk
    print('Linux')
elif OS == 'Windows':
    # %matplotlib qt
    print('Windows')
elif OS == 'Darwin':
    # %matplotlib tk
    print('Mac (Funciona?)')
else:
    print('OS not detected :-|')

import sys
from pathlib import Path
sys.path.insert(1, '../src/SEIRHVD/')
sys.path.insert(1, '../src/utils/')
sys.path.insert(1, 'src/SEIRHVD/')
sys.path.insert(1, 'src/utils/')

from class_SEIRHUVD5 import SEIRHVD 
from Quarantine import Quarantine
from Quarantine import SeroPrevDynamics
from importdata import ImportData
import Events

import json
from pandas.core.base import DataError
import requests
from requests.auth import HTTPBasicAuth
import pandas as pd
import matplotlib

from datetime import date
# Out:
# Linux

# %% [markdown]
# ## Time Variables
# Declare Initial date for simulating and data fitting

# %%
# First simulation Initial date
initdate = datetime(2020,11,26)
# Date for change in SeroPrevalence
SPchange_date = datetime(2020,7,25)

# Current date
currentdate = datetime.now()
currentday = (currentdate - initdate).days

fiestaspatrias = datetime(2020,9,18)
fiestaspatrias_day = (fiestaspatrias-initdate).days
plebiscito = datetime(2020,10,25)
plebiscito_day = (plebiscito-initdate).days

navidad = datetime(2020,12,25)
navidad_day = (navidad-initdate).days

newyear = datetime(2020,12,31)
newyear_day = (newyear-initdate).days

today = datetime.today()
today_day = (today-initdate).days

# %% [markdown]
# ## Import Data
# To import data we use an ImportData object which is initialized with the region's cut and the initial date. state region is represented by cut = 14.

# %%
def dataretriever(user=None,password=None):
    # Esta funcion devolvera una funcion de request        
    def request(endpoint):
        if user:
            aux = requests.get('https://api.cv19gm.org/'+endpoint, auth=HTTPBasicAuth(user, password))
            if aux.status_code == 401:
                raise Exception('Wrong Credentials')
            else:
                print('Logged in successfully')
        else:
            aux = requests.get('http://192.168.2.223:5006/'+endpoint)
        return aux
    return request
def timeJStoPy(t):
    return datetime.strptime(t[:10],'%Y-%m-%d')
def timetxttoDatetime(t):
    return datetime.strptime(t,'%Y-%m-%d')

# %%
request = dataretriever()

# %%
request2 = dataretriever(user = 'afosr',password = '5pI50sOjPTDlpH')

# %%
request2('getComunas').json()
# Out:
# Logged in successfully
# [{'state': '01',
#   'state_name': 'Tarapacá',
#   'province': '011',
#   'province_name': 'Iquique',
#   'county': '01101',
#   'county_name': 'Iquique',
#   'ss': '011',
#   'ss_name': 'Servicio de Salud Iquique',
#   'male_pop': 112479,
#   'female_pop': 110984,
#   'total_pop': 223463,
#   'area': 2242.1,
#   'density': 85.4},
#  {'state': '01',
#   'state_name': 'Tarapacá',
#   'province': '011',
#   'province_name': 'Iquique',
#   'county': '01107',
#   'county_name': 'Alto Hospicio',
#   'ss': '011',
#   'ss_name': 'Servicio de Salud Iquique',
#   'male_pop': 65487,
#   'female_pop': 64512,
#   'total_pop': 129999,
#   'area': 572.9,
#   'density': 189.2},
#  {'state': '01',
#   'state_name': 'Tarapacá',
#   'province': '014',
#   'province_name': 'Tamarugal',
#   'county': '01401',
#   'county_name': 'Pozo Almonte',
#   'ss': '011',
#   'ss_name': 'Servicio de Salud Iquique',
#   'male_pop': 9077,
#   'female_pop': 8318,
#   'total_pop': 17395,
#   'area': 13765.8,
#   'density': 1.1},
#  {'state': '01',
#   'state_name': 'Tarapacá',
#   'province': '014',
#   'province_name': 'Tamarugal',
#   'county': '01402',
#   'county_name': 'Camiña',
#   'ss': '011',
#   'ss_name': 'Servicio de Salud Iquique',
#   'male_pop': 705,
#   'female_pop': 670,
#   'total_pop': 1375,
#   'area': 2200.2,
#   'density': 0.6},
#  {'state': '01',
#   'state_name': 'Tarapacá',
#   'province': '014',
#   'province_name': 'Tamarugal',
#   'county': '01403',
#   'county_name': 'Colchane',
#   'ss': '011',
#   'ss_name': 'Servicio de Salud Iquique',
#   'male_pop': 826,
#   'female_pop': 757,
#   'total_pop': 1583,
#   'area': 4015.6,
#   'density': 0.4},
#  {'state': '01',
#   'state_name': 'Tarapacá',
#   'province': '014',
#   'province_name': 'Tamarugal',
#   'county': '01404',
#   'county_name': 'Huara',
#   'ss': '011',
#   'ss_name': 'Servicio de Salud Iquique',
#   'male_pop': 1559,
#   'female_pop': 1441,
#   'total_pop': 3000,
#   'area': 10474.6,
#   'density': 0.3},
#  {'state': '01',
#   'state_name': 'Tarapacá',
#   'province': '014',
#   'province_name': 'Tamarugal',
#   'county': '01405',
#   'county_name': 'Pica',
#   'ss': '011',
#   'ss_name': 'Servicio de Salud Iquique',
#   'male_pop': 3012,
#   'female_pop': 2946,
#   'total_pop': 5958,
#   'area': 8934.3,
#   'density': 1},
#  {'state': '02',
#   'state_name': 'Antofagasta',
#   'province': '021',
#   'province_name': 'Antofagasta',
#   'county': '02101',
#   'county_name': 'Antofagasta',
#   'ss': '021',
#   'ss_name': 'Servicio de Salud Antofagasta',
#   'male_pop': 213732,
#   'female_pop': 211993,
#   'total_pop': 425725,
#   'area': 30718.1,
#   'density': 11.8},
#  {'state': '02',
#   'state_name': 'Antofagasta',
#   'province': '021',
#   'province_name': 'Antofagasta',
#   'county': '02102',
#   'county_name': 'Mejillones',
#   'ss': '021',
#   'ss_name': 'Servicio de Salud Antofagasta',
#   'male_pop': 7716,
#   'female_pop': 7060,
#   'total_pop': 14776,
#   'area': 3803.9,
#   'density': 3.5},
#  {'state': '02',
#   'state_name': 'Antofagasta',
#   'province': '021',
#   'province_name': 'Antofagasta',
#   'county': '02103',
#   'county_name': 'Sierra Gorda',
#   'ss': '021',
#   'ss_name': 'Servicio de Salud Antofagasta',
#   'male_pop': 923,
#   'female_pop': 823,
#   'total_pop': 1746,
#   'area': 12886,
#   'density': 0.8},
#  {'state': '02',
#   'state_name': 'Antofagasta',
#   'province': '021',
#   'province_name': 'Antofagasta',
#   'county': '02104',
#   'county_name': 'Taltal',
#   'ss': '021',
#   'ss_name': 'Servicio de Salud Antofagasta',
#   'male_pop': 6958,
#   'female_pop': 6699,
#   'total_pop': 13657,
#   'area': 20405.1,
#   'density': 0.7},
#  {'state': '02',
#   'state_name': 'Antofagasta',
#   'province': '022',
#   'province_name': 'El Loa',
#   'county': '02201',
#   'county_name': 'Calama',
#   'ss': '021',
#   'ss_name': 'Servicio de Salud Antofagasta',
#   'male_pop': 95909,
#   'female_pop': 94427,
#   'total_pop': 190336,
#   'area': 15596.9,
#   'density': 10.6},
#  {'state': '02',
#   'state_name': 'Antofagasta',
#   'province': '022',
#   'province_name': 'El Loa',
#   'county': '02202',
#   'county_name': 'Ollagüe',
#   'ss': '021',
#   'ss_name': 'Servicio de Salud Antofagasta',
#   'male_pop': 152,
#   'female_pop': 135,
#   'total_pop': 287,
#   'area': 2964,
#   'density': 0.1},
#  {'state': '02',
#   'state_name': 'Antofagasta',
#   'province': '022',
#   'province_name': 'El Loa',
#   'county': '02203',
#   'county_name': 'San Pedro de Atacama',
#   'ss': '021',
#   'ss_name': 'Servicio de Salud Antofagasta',
#   'male_pop': 5262,
#   'female_pop': 5172,
#   'total_pop': 10434,
#   'area': 23439,
#   'density': 0.5},
#  {'state': '02',
#   'state_name': 'Antofagasta',
#   'province': '023',
#   'province_name': 'Tocopilla',
#   'county': '02301',
#   'county_name': 'Tocopilla',
#   'ss': '021',
#   'ss_name': 'Servicio de Salud Antofagasta',
#   'male_pop': 14059,
#   'female_pop': 14020,
#   'total_pop': 28079,
#   'area': 4038.8,
#   'density': 6.2},
#  {'state': '02',
#   'state_name': 'Antofagasta',
#   'province': '023',
#   'province_name': 'Tocopilla',
#   'county': '02302',
#   'county_name': 'María Elena',
#   'ss': '021',
#   'ss_name': 'Servicio de Salud Antofagasta',
#   'male_pop': 3499,
#   'female_pop': 3315,
#   'total_pop': 6814,
#   'area': 12197,
#   'density': 0.5},
#  {'state': '03',
#   'state_name': 'Atacama',
#   'province': '031',
#   'province_name': 'Copiapó',
#   'county': '03101',
#   'county_name': 'Copiapó',
#   'ss': '031',
#   'ss_name': 'Servicio de Salud Atacama',
#   'male_pop': 86464,
#   'female_pop': 85302,
#   'total_pop': 171766,
#   'area': 16681.3,
#   'density': 9.2},
#  {'state': '03',
#   'state_name': 'Atacama',
#   'province': '031',
#   'province_name': 'Copiapó',
#   'county': '03102',
#   'county_name': 'Caldera',
#   'ss': '031',
#   'ss_name': 'Servicio de Salud Atacama',
#   'male_pop': 9885,
#   'female_pop': 9541,
#   'total_pop': 19426,
#   'area': 4666.6,
#   'density': 3.8},
#  {'state': '03',
#   'state_name': 'Atacama',
#   'province': '031',
#   'province_name': 'Copiapó',
#   'county': '03103',
#   'county_name': 'Tierra Amarilla',
#   'ss': '031',
#   'ss_name': 'Servicio de Salud Atacama',
#   'male_pop': 7408,
#   'female_pop': 6904,
#   'total_pop': 14312,
#   'area': 11191,
#   'density': 1.3},
#  {'state': '03',
#   'state_name': 'Atacama',
#   'province': '032',
#   'province_name': 'Chañaral',
#   'county': '03201',
#   'county_name': 'Chañaral',
#   'ss': '031',
#   'ss_name': 'Servicio de Salud Atacama',
#   'male_pop': 6685,
#   'female_pop': 6479,
#   'total_pop': 13164,
#   'area': 5772,
#   'density': 2.1},
#  {'state': '03',
#   'state_name': 'Atacama',
#   'province': '032',
#   'province_name': 'Chañaral',
#   'county': '03202',
#   'county_name': 'Diego de Almagro',
#   'ss': '031',
#   'ss_name': 'Servicio de Salud Atacama',
#   'male_pop': 7312,
#   'female_pop': 7046,
#   'total_pop': 14358,
#   'area': 18664,
#   'density': 0.8},
#  {'state': '03',
#   'state_name': 'Atacama',
#   'province': '033',
#   'province_name': 'Huasco',
#   'county': '03301',
#   'county_name': 'Vallenar',
#   'ss': '031',
#   'ss_name': 'Servicio de Salud Atacama',
#   'male_pop': 28591,
#   'female_pop': 28418,
#   'total_pop': 57009,
#   'area': 7084,
#   'density': 7.3},
#  {'state': '03',
#   'state_name': 'Atacama',
#   'province': '033',
#   'province_name': 'Huasco',
#   'county': '03302',
#   'county_name': 'Alto del Carmen',
#   'ss': '031',
#   'ss_name': 'Servicio de Salud Atacama',
#   'male_pop': 2960,
#   'female_pop': 2769,
#   'total_pop': 5729,
#   'area': 5939,
#   'density': 0.9},
#  {'state': '03',
#   'state_name': 'Atacama',
#   'province': '033',
#   'province_name': 'Huasco',
#   'county': '03303',
#   'county_name': 'Freirina',
#   'ss': '031',
#   'ss_name': 'Servicio de Salud Atacama',
#   'male_pop': 3890,
#   'female_pop': 3791,
#   'total_pop': 7681,
#   'area': 3207.9,
#   'density': 2.2},
#  {'state': '03',
#   'state_name': 'Atacama',
#   'province': '033',
#   'province_name': 'Huasco',
#   'county': '03304',
#   'county_name': 'Huasco',
#   'ss': '031',
#   'ss_name': 'Servicio de Salud Atacama',
#   'male_pop': 5744,
#   'female_pop': 5520,
#   'total_pop': 11264,
#   'area': 1601.4,
#   'density': 6.3},
#  {'state': '04',
#   'state_name': 'Coquimbo',
#   'province': '041',
#   'province_name': 'Elqui',
#   'county': '04101',
#   'county_name': 'La Serena',
#   'ss': '041',
#   'ss_name': 'Servicio de Salud Coquimbo',
#   'male_pop': 121768,
#   'female_pop': 127888,
#   'total_pop': 249656,
#   'area': 1892.8,
#   'density': 116.8},
#  {'state': '04',
#   'state_name': 'Coquimbo',
#   'province': '041',
#   'province_name': 'Elqui',
#   'county': '04102',
#   'county_name': 'Coquimbo',
#   'ss': '041',
#   'ss_name': 'Servicio de Salud Coquimbo',
#   'male_pop': 125378,
#   'female_pop': 131357,
#   'total_pop': 256735,
#   'area': 1429,
#   'density': 159.4},
#  {'state': '04',
#   'state_name': 'Coquimbo',
#   'province': '041',
#   'province_name': 'Elqui',
#   'county': '04103',
#   'county_name': 'Andacollo',
#   'ss': '041',
#   'ss_name': 'Servicio de Salud Coquimbo',
#   'male_pop': 5852,
#   'female_pop': 5939,
#   'total_pop': 11791,
#   'area': 310,
#   'density': 35.7},
#  {'state': '04',
#   'state_name': 'Coquimbo',
#   'province': '041',
#   'province_name': 'Elqui',
#   'county': '04104',
#   'county_name': 'La Higuera',
#   'ss': '041',
#   'ss_name': 'Servicio de Salud Coquimbo',
#   'male_pop': 2245,
#   'female_pop': 2205,
#   'total_pop': 4450,
#   'area': 4158.2,
#   'density': 1},
#  {'state': '04',
#   'state_name': 'Coquimbo',
#   'province': '041',
#   'province_name': 'Elqui',
#   'county': '04105',
#   'county_name': 'Paiguano',
#   'ss': '041',
#   'ss_name': 'Servicio de Salud Coquimbo',
#   'male_pop': 2306,
#   'female_pop': 2369,
#   'total_pop': 4675,
#   'area': 1495,
#   'density': 3},
#  {'state': '04',
#   'state_name': 'Coquimbo',
#   'province': '041',
#   'province_name': 'Elqui',
#   'county': '04106',
#   'county_name': 'Vicuña',
#   'ss': '041',
#   'ss_name': 'Servicio de Salud Coquimbo',
#   'male_pop': 14665,
#   'female_pop': 15076,
#   'total_pop': 29741,
#   'area': 7610,
#   'density': 3.7},
#  {'state': '04',
#   'state_name': 'Coquimbo',
#   'province': '042',
#   'province_name': 'Choapa',
#   'county': '04201',
#   'county_name': 'Illapel',
#   'ss': '041',
#   'ss_name': 'Servicio de Salud Coquimbo',
#   'male_pop': 15962,
#   'female_pop': 16839,
#   'total_pop': 32801,
#   'area': 2629,
#   'density': 11.7},
#  {'state': '04',
#   'state_name': 'Coquimbo',
#   'province': '042',
#   'province_name': 'Choapa',
#   'county': '04202',
#   'county_name': 'Canela',
#   'ss': '041',
#   'ss_name': 'Servicio de Salud Coquimbo',
#   'male_pop': 4769,
#   'female_pop': 4777,
#   'total_pop': 9546,
#   'area': 2196.6,
#   'density': 4.1},
#  {'state': '04',
#   'state_name': 'Coquimbo',
#   'province': '042',
#   'province_name': 'Choapa',
#   'county': '04203',
#   'county_name': 'Los Vilos',
#   'ss': '041',
#   'ss_name': 'Servicio de Salud Coquimbo',
#   'male_pop': 11728,
#   'female_pop': 11646,
#   'total_pop': 23374,
#   'area': 1823.8,
#   'density': 11.7},
#  {'state': '04',
#   'state_name': 'Coquimbo',
#   'province': '042',
#   'province_name': 'Choapa',
#   'county': '04204',
#   'county_name': 'Salamanca',
#   'ss': '041',
#   'ss_name': 'Servicio de Salud Coquimbo',
#   'male_pop': 14508,
#   'female_pop': 14602,
#   'total_pop': 29110,
#   'area': 3445,
#   'density': 8.5},
#  {'state': '04',
#   'state_name': 'Coquimbo',
#   'province': '043',
#   'province_name': 'Limarí',
#   'county': '04301',
#   'county_name': 'Ovalle',
#   'ss': '041',
#   'ss_name': 'Servicio de Salud Coquimbo',
#   'male_pop': 59332,
#   'female_pop': 61937,
#   'total_pop': 121269,
#   'area': 3835,
#   'density': 29},
#  {'state': '04',
#   'state_name': 'Coquimbo',
#   'province': '043',
#   'province_name': 'Limarí',
#   'county': '04302',
#   'county_name': 'Combarbalá',
#   'ss': '041',
#   'ss_name': 'Servicio de Salud Coquimbo',
#   'male_pop': 6847,
#   'female_pop': 7037,
#   'total_pop': 13884,
#   'area': 2257.5,
#   'density': 5.9},
#  {'state': '04',
#   'state_name': 'Coquimbo',
#   'province': '043',
#   'province_name': 'Limarí',
#   'county': '04303',
#   'county_name': 'Monte Patria',
#   'ss': '041',
#   'ss_name': 'Servicio de Salud Coquimbo',
#   'male_pop': 16092,
#   'female_pop': 16435,
#   'total_pop': 32527,
#   'area': 4366.9,
#   'density': 7},
#  {'state': '04',
#   'state_name': 'Coquimbo',
#   'province': '043',
#   'province_name': 'Limarí',
#   'county': '04304',
#   'county_name': 'Punitaqui',
#   'ss': '041',
#   'ss_name': 'Servicio de Salud Coquimbo',
#   'male_pop': 6010,
#   'female_pop': 6155,
#   'total_pop': 12165,
#   'area': 1339,
#   'density': 8.2},
#  {'state': '04',
#   'state_name': 'Coquimbo',
#   'province': '043',
#   'province_name': 'Limarí',
#   'county': '04305',
#   'county_name': 'Río Hurtado',
#   'ss': '041',
#   'ss_name': 'Servicio de Salud Coquimbo',
#   'male_pop': 2152,
#   'female_pop': 2220,
#   'total_pop': 4372,
#   'area': 2180,
#   'density': 2},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '051',
#   'province_name': 'Valparaíso',
#   'county': '05101',
#   'county_name': 'Valparaíso',
#   'ss': '052',
#   'ss_name': 'Servicio de Salud Valparaiso - San Antonio',
#   'male_pop': 155018,
#   'female_pop': 160714,
#   'total_pop': 315732,
#   'area': 401.6,
#   'density': 738.7},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '051',
#   'province_name': 'Valparaíso',
#   'county': '05102',
#   'county_name': 'Casablanca',
#   'ss': '052',
#   'ss_name': 'Servicio de Salud Valparaiso - San Antonio',
#   'male_pop': 14399,
#   'female_pop': 14771,
#   'total_pop': 29170,
#   'area': 953,
#   'density': 28.2},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '051',
#   'province_name': 'Valparaíso',
#   'county': '05103',
#   'county_name': 'Concón',
#   'ss': '053',
#   'ss_name': 'Servicio de Salud Viña del Mar',
#   'male_pop': 22442,
#   'female_pop': 23447,
#   'total_pop': 45889,
#   'area': 76,
#   'density': 554.6},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '051',
#   'province_name': 'Valparaíso',
#   'county': '05104',
#   'county_name': 'Juan Fernández',
#   'ss': '052',
#   'ss_name': 'Servicio de Salud Valparaiso - San Antonio',
#   'male_pop': 523,
#   'female_pop': 510,
#   'total_pop': 1033,
#   'area': 149.4,
#   'density': 6.2},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '051',
#   'province_name': 'Valparaíso',
#   'county': '05105',
#   'county_name': 'Puchuncaví',
#   'ss': '053',
#   'ss_name': 'Servicio de Salud Viña del Mar',
#   'male_pop': 9971,
#   'female_pop': 10100,
#   'total_pop': 20071,
#   'area': 300,
#   'density': 61.8},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '051',
#   'province_name': 'Valparaíso',
#   'county': '05107',
#   'county_name': 'Quintero',
#   'ss': '053',
#   'ss_name': 'Servicio de Salud Viña del Mar',
#   'male_pop': 17858,
#   'female_pop': 18277,
#   'total_pop': 36135,
#   'area': 148,
#   'density': 215.7},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '051',
#   'province_name': 'Valparaíso',
#   'county': '05109',
#   'county_name': 'Viña del Mar',
#   'ss': '053',
#   'ss_name': 'Servicio de Salud Viña del Mar',
#   'male_pop': 174976,
#   'female_pop': 186395,
#   'total_pop': 361371,
#   'area': 121.6,
#   'density': 2748.8},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '052',
#   'province_name': 'Isla de Pascua',
#   'county': '05201',
#   'county_name': 'Isla de Pascua',
#   'ss': '052',
#   'ss_name': 'Servicio de Salud Valparaiso - San Antonio',
#   'male_pop': 4089,
#   'female_pop': 4188,
#   'total_pop': 8277,
#   'area': 163.6,
#   'density': 47.4},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '053',
#   'province_name': 'Los Andes',
#   'county': '05301',
#   'county_name': 'Los Andes',
#   'ss': '051',
#   'ss_name': 'Servicio de Salud Aconcagua',
#   'male_pop': 33314,
#   'female_pop': 34779,
#   'total_pop': 68093,
#   'area': 1248,
#   'density': 53.5},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '053',
#   'province_name': 'Los Andes',
#   'county': '05302',
#   'county_name': 'Calle Larga',
#   'ss': '051',
#   'ss_name': 'Servicio de Salud Aconcagua',
#   'male_pop': 8119,
#   'female_pop': 8363,
#   'total_pop': 16482,
#   'area': 321.7,
#   'density': 46.1},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '053',
#   'province_name': 'Los Andes',
#   'county': '05303',
#   'county_name': 'Rinconada',
#   'ss': '051',
#   'ss_name': 'Servicio de Salud Aconcagua',
#   'male_pop': 5592,
#   'female_pop': 5671,
#   'total_pop': 11263,
#   'area': 122.5,
#   'density': 89.3},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '053',
#   'province_name': 'Los Andes',
#   'county': '05304',
#   'county_name': 'San Esteban',
#   'ss': '051',
#   'ss_name': 'Servicio de Salud Aconcagua',
#   'male_pop': 10172,
#   'female_pop': 10471,
#   'total_pop': 20643,
#   'area': 681,
#   'density': 27.7},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '054',
#   'province_name': 'Petorca',
#   'county': '05401',
#   'county_name': 'La Ligua',
#   'ss': '053',
#   'ss_name': 'Servicio de Salud Viña del Mar',
#   'male_pop': 18546,
#   'female_pop': 19193,
#   'total_pop': 37739,
#   'area': 1163,
#   'density': 30.4},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '054',
#   'province_name': 'Petorca',
#   'county': '05402',
#   'county_name': 'Cabildo',
#   'ss': '053',
#   'ss_name': 'Servicio de Salud Viña del Mar',
#   'male_pop': 10168,
#   'female_pop': 10495,
#   'total_pop': 20663,
#   'area': 1455,
#   'density': 13.3},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '054',
#   'province_name': 'Petorca',
#   'county': '05403',
#   'county_name': 'Papudo',
#   'ss': '053',
#   'ss_name': 'Servicio de Salud Viña del Mar',
#   'male_pop': 3090,
#   'female_pop': 3111,
#   'total_pop': 6201,
#   'area': 64.3,
#   'density': 98.9},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '054',
#   'province_name': 'Petorca',
#   'county': '05404',
#   'county_name': 'Petorca',
#   'ss': '053',
#   'ss_name': 'Servicio de Salud Viña del Mar',
#   'male_pop': 5246,
#   'female_pop': 5312,
#   'total_pop': 10558,
#   'area': 1517,
#   'density': 6.5},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '054',
#   'province_name': 'Petorca',
#   'county': '05405',
#   'county_name': 'Zapallar',
#   'ss': '053',
#   'ss_name': 'Servicio de Salud Viña del Mar',
#   'male_pop': 3976,
#   'female_pop': 4018,
#   'total_pop': 7994,
#   'area': 288,
#   'density': 25.5},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '055',
#   'province_name': 'Quillota',
#   'county': '05501',
#   'county_name': 'Quillota',
#   'ss': '053',
#   'ss_name': 'Servicio de Salud Viña del Mar',
#   'male_pop': 47609,
#   'female_pop': 49963,
#   'total_pop': 97572,
#   'area': 302,
#   'density': 299.5},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '055',
#   'province_name': 'Quillota',
#   'county': '05502',
#   'county_name': 'Calera',
#   'ss': '053',
#   'ss_name': 'Servicio de Salud Viña del Mar',
#   'male_pop': 26287,
#   'female_pop': 27304,
#   'total_pop': 53591,
#   'area': 60.5,
#   'density': 835.4},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '055',
#   'province_name': 'Quillota',
#   'county': '05503',
#   'county_name': 'Hijuelas',
#   'ss': '053',
#   'ss_name': 'Servicio de Salud Viña del Mar',
#   'male_pop': 9494,
#   'female_pop': 9605,
#   'total_pop': 19099,
#   'area': 267,
#   'density': 67.4},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '055',
#   'province_name': 'Quillota',
#   'county': '05504',
#   'county_name': 'La Cruz',
#   'ss': '053',
#   'ss_name': 'Servicio de Salud Viña del Mar',
#   'male_pop': 12377,
#   'female_pop': 12944,
#   'total_pop': 25321,
#   'area': 78,
#   'density': 283.3},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '055',
#   'province_name': 'Quillota',
#   'county': '05506',
#   'county_name': 'Nogales',
#   'ss': '053',
#   'ss_name': 'Servicio de Salud Viña del Mar',
#   'male_pop': 11586,
#   'female_pop': 11904,
#   'total_pop': 23490,
#   'area': 405,
#   'density': 54.6},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '056',
#   'province_name': 'San Antonio',
#   'county': '05601',
#   'county_name': 'San Antonio',
#   'ss': '052',
#   'ss_name': 'Servicio de Salud Valparaiso - San Antonio',
#   'male_pop': 47484,
#   'female_pop': 49277,
#   'total_pop': 96761,
#   'area': 405,
#   'density': 225.6},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '056',
#   'province_name': 'San Antonio',
#   'county': '05602',
#   'county_name': 'Algarrobo',
#   'ss': '052',
#   'ss_name': 'Servicio de Salud Valparaiso - San Antonio',
#   'male_pop': 7469,
#   'female_pop': 7705,
#   'total_pop': 15174,
#   'area': 176,
#   'density': 78.5},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '056',
#   'province_name': 'San Antonio',
#   'county': '05603',
#   'county_name': 'Cartagena',
#   'ss': '052',
#   'ss_name': 'Servicio de Salud Valparaiso - San Antonio',
#   'male_pop': 12521,
#   'female_pop': 12836,
#   'total_pop': 25357,
#   'area': 246,
#   'density': 92.4},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '056',
#   'province_name': 'San Antonio',
#   'county': '05604',
#   'county_name': 'El Quisco',
#   'ss': '052',
#   'ss_name': 'Servicio de Salud Valparaiso - San Antonio',
#   'male_pop': 8742,
#   'female_pop': 9000,
#   'total_pop': 17742,
#   'area': 51,
#   'density': 312.8},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '056',
#   'province_name': 'San Antonio',
#   'county': '05605',
#   'county_name': 'El Tabo',
#   'ss': '052',
#   'ss_name': 'Servicio de Salud Valparaiso - San Antonio',
#   'male_pop': 7125,
#   'female_pop': 7213,
#   'total_pop': 14338,
#   'area': 99,
#   'density': 134.2},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '056',
#   'province_name': 'San Antonio',
#   'county': '05606',
#   'county_name': 'Santo Domingo',
#   'ss': '052',
#   'ss_name': 'Servicio de Salud Valparaiso - San Antonio',
#   'male_pop': 5914,
#   'female_pop': 6020,
#   'total_pop': 11934,
#   'area': 536,
#   'density': 20.3},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '057',
#   'province_name': 'San Felipe',
#   'county': '05701',
#   'county_name': 'San Felipe',
#   'ss': '051',
#   'ss_name': 'Servicio de Salud Aconcagua',
#   'male_pop': 40846,
#   'female_pop': 42648,
#   'total_pop': 83494,
#   'area': 186,
#   'density': 413.1},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '057',
#   'province_name': 'San Felipe',
#   'county': '05702',
#   'county_name': 'Catemu',
#   'ss': '051',
#   'ss_name': 'Servicio de Salud Aconcagua',
#   'male_pop': 7553,
#   'female_pop': 7660,
#   'total_pop': 15213,
#   'area': 361.6,
#   'density': 38.7},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '057',
#   'province_name': 'San Felipe',
#   'county': '05703',
#   'county_name': 'Llaillay',
#   'ss': '051',
#   'ss_name': 'Servicio de Salud Aconcagua',
#   'male_pop': 13125,
#   'female_pop': 13408,
#   'total_pop': 26533,
#   'area': 349.1,
#   'density': 70.5},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '057',
#   'province_name': 'San Felipe',
#   'county': '05704',
#   'county_name': 'Panquehue',
#   'ss': '051',
#   'ss_name': 'Servicio de Salud Aconcagua',
#   'male_pop': 3802,
#   'female_pop': 3831,
#   'total_pop': 7633,
#   'area': 121.9,
#   'density': 59.7},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '057',
#   'province_name': 'San Felipe',
#   'county': '05705',
#   'county_name': 'Putaendo',
#   'ss': '051',
#   'ss_name': 'Servicio de Salud Aconcagua',
#   'male_pop': 8725,
#   'female_pop': 8920,
#   'total_pop': 17645,
#   'area': 1474,
#   'density': 11.4},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '057',
#   'province_name': 'San Felipe',
#   'county': '05706',
#   'county_name': 'Santa María',
#   'ss': '051',
#   'ss_name': 'Servicio de Salud Aconcagua',
#   'male_pop': 8105,
#   'female_pop': 8262,
#   'total_pop': 16367,
#   'area': 166.3,
#   'density': 91.7},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '058',
#   'province_name': 'Marga Marga',
#   'county': '05801',
#   'county_name': 'Quilpué',
#   'ss': '053',
#   'ss_name': 'Servicio de Salud Viña del Mar',
#   'male_pop': 81080,
#   'female_pop': 86005,
#   'total_pop': 167085,
#   'area': 536.9,
#   'density': 282.6},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '058',
#   'province_name': 'Marga Marga',
#   'county': '05802',
#   'county_name': 'Limache',
#   'ss': '053',
#   'ss_name': 'Servicio de Salud Viña del Mar',
#   'male_pop': 24363,
#   'female_pop': 25568,
#   'total_pop': 49931,
#   'area': 294,
#   'density': 156.9},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '058',
#   'province_name': 'Marga Marga',
#   'county': '05803',
#   'county_name': 'Olmué',
#   'ss': '053',
#   'ss_name': 'Servicio de Salud Viña del Mar',
#   'male_pop': 9485,
#   'female_pop': 9781,
#   'total_pop': 19266,
#   'area': 232,
#   'density': 75.5},
#  {'state': '05',
#   'state_name': 'Valparaíso',
#   'province': '058',
#   'province_name': 'Marga Marga',
#   'county': '05804',
#   'county_name': 'Villa Alemana',
#   'ss': '053',
#   'ss_name': 'Servicio de Salud Viña del Mar',
#   'male_pop': 67481,
#   'female_pop': 71829,
#   'total_pop': 139310,
#   'area': 97,
#   'density': 1304.6},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '061',
#   'province_name': 'Cachapoal',
#   'county': '06101',
#   'county_name': 'Rancagua',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 132062,
#   'female_pop': 133149,
#   'total_pop': 265211,
#   'area': 260.3,
#   'density': 928.7},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '061',
#   'province_name': 'Cachapoal',
#   'county': '06102',
#   'county_name': 'Codegua',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 7082,
#   'female_pop': 7014,
#   'total_pop': 14096,
#   'area': 287,
#   'density': 45.3},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '061',
#   'province_name': 'Cachapoal',
#   'county': '06103',
#   'county_name': 'Coinco',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 3952,
#   'female_pop': 3879,
#   'total_pop': 7831,
#   'area': 98,
#   'density': 75.1},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '061',
#   'province_name': 'Cachapoal',
#   'county': '06104',
#   'county_name': 'Coltauco',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 10672,
#   'female_pop': 10591,
#   'total_pop': 21263,
#   'area': 225,
#   'density': 87.1},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '061',
#   'province_name': 'Cachapoal',
#   'county': '06105',
#   'county_name': 'Doñihue',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 11375,
#   'female_pop': 11325,
#   'total_pop': 22700,
#   'area': 78,
#   'density': 267.8},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '061',
#   'province_name': 'Cachapoal',
#   'county': '06106',
#   'county_name': 'Graneros',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 18278,
#   'female_pop': 18226,
#   'total_pop': 36504,
#   'area': 113,
#   'density': 295.9},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '061',
#   'province_name': 'Cachapoal',
#   'county': '06107',
#   'county_name': 'Las Cabras',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 13539,
#   'female_pop': 13210,
#   'total_pop': 26749,
#   'area': 749,
#   'density': 32.9},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '061',
#   'province_name': 'Cachapoal',
#   'county': '06108',
#   'county_name': 'Machalí',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 29844,
#   'female_pop': 30069,
#   'total_pop': 59913,
#   'area': 2597,
#   'density': 20.2},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '061',
#   'province_name': 'Cachapoal',
#   'county': '06109',
#   'county_name': 'Malloa',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 7145,
#   'female_pop': 7018,
#   'total_pop': 14163,
#   'area': 113,
#   'density': 118.7},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '061',
#   'province_name': 'Cachapoal',
#   'county': '06110',
#   'county_name': 'Mostazal',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 13754,
#   'female_pop': 13708,
#   'total_pop': 27462,
#   'area': 524,
#   'density': 48.4},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '061',
#   'province_name': 'Cachapoal',
#   'county': '06111',
#   'county_name': 'Olivar',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 7351,
#   'female_pop': 7273,
#   'total_pop': 14624,
#   'area': 45,
#   'density': 302.4},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '061',
#   'province_name': 'Cachapoal',
#   'county': '06112',
#   'county_name': 'Peumo',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 7504,
#   'female_pop': 7448,
#   'total_pop': 14952,
#   'area': 153.1,
#   'density': 93.5},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '061',
#   'province_name': 'Cachapoal',
#   'county': '06113',
#   'county_name': 'Pichidegua',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 10471,
#   'female_pop': 10272,
#   'total_pop': 20743,
#   'area': 320,
#   'density': 61.6},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '061',
#   'province_name': 'Cachapoal',
#   'county': '06114',
#   'county_name': 'Quinta de Tilcoco',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 6963,
#   'female_pop': 6914,
#   'total_pop': 13877,
#   'area': 93,
#   'density': 139.8},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '061',
#   'province_name': 'Cachapoal',
#   'county': '06115',
#   'county_name': 'Rengo',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 31759,
#   'female_pop': 31951,
#   'total_pop': 63710,
#   'area': 755,
#   'density': 77.9},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '061',
#   'province_name': 'Cachapoal',
#   'county': '06116',
#   'county_name': 'Requínoa',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 15263,
#   'female_pop': 15108,
#   'total_pop': 30371,
#   'area': 673,
#   'density': 41.6},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '061',
#   'province_name': 'Cachapoal',
#   'county': '06117',
#   'county_name': 'San Vicente',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 25357,
#   'female_pop': 25260,
#   'total_pop': 50617,
#   'area': 497.8,
#   'density': 93.9},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '062',
#   'province_name': 'Cardenal Caro',
#   'county': '06201',
#   'county_name': 'Pichilemu',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 9012,
#   'female_pop': 8870,
#   'total_pop': 17882,
#   'area': 749.1,
#   'density': 21.9},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '062',
#   'province_name': 'Cardenal Caro',
#   'county': '06202',
#   'county_name': 'La Estrella',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 1588,
#   'female_pop': 1526,
#   'total_pop': 3114,
#   'area': 435,
#   'density': 7},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '062',
#   'province_name': 'Cardenal Caro',
#   'county': '06203',
#   'county_name': 'Litueche',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 3438,
#   'female_pop': 3327,
#   'total_pop': 6765,
#   'area': 619,
#   'density': 10.2},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '062',
#   'province_name': 'Cardenal Caro',
#   'county': '06204',
#   'county_name': 'Marchihue',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 3838,
#   'female_pop': 3794,
#   'total_pop': 7632,
#   'area': 660,
#   'density': 11.1},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '062',
#   'province_name': 'Cardenal Caro',
#   'county': '06205',
#   'county_name': 'Navidad',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 3503,
#   'female_pop': 3401,
#   'total_pop': 6904,
#   'area': 300,
#   'density': 22.1},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '062',
#   'province_name': 'Cardenal Caro',
#   'county': '06206',
#   'county_name': 'Paredones',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 3229,
#   'female_pop': 3120,
#   'total_pop': 6349,
#   'area': 562,
#   'density': 11},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '063',
#   'province_name': 'Colchagua',
#   'county': '06301',
#   'county_name': 'San Fernando',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 38982,
#   'female_pop': 39660,
#   'total_pop': 78642,
#   'area': 2441,
#   'density': 30.3},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '063',
#   'province_name': 'Colchagua',
#   'county': '06302',
#   'county_name': 'Chépica',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 8008,
#   'female_pop': 7917,
#   'total_pop': 15925,
#   'area': 503,
#   'density': 29.9},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '063',
#   'province_name': 'Colchagua',
#   'county': '06303',
#   'county_name': 'Chimbarongo',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 18958,
#   'female_pop': 18738,
#   'total_pop': 37696,
#   'area': 498,
#   'density': 71.1},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '063',
#   'province_name': 'Colchagua',
#   'county': '06304',
#   'county_name': 'Lolol',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 3678,
#   'female_pop': 3611,
#   'total_pop': 7289,
#   'area': 597,
#   'density': 11.4},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '063',
#   'province_name': 'Colchagua',
#   'county': '06305',
#   'county_name': 'Nancagua',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 9560,
#   'female_pop': 9581,
#   'total_pop': 19141,
#   'area': 111,
#   'density': 160.7},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '063',
#   'province_name': 'Colchagua',
#   'county': '06306',
#   'county_name': 'Palmilla',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 6703,
#   'female_pop': 6596,
#   'total_pop': 13299,
#   'area': 237,
#   'density': 52.7},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '063',
#   'province_name': 'Colchagua',
#   'county': '06307',
#   'county_name': 'Peralillo',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 5948,
#   'female_pop': 5900,
#   'total_pop': 11848,
#   'area': 282.6,
#   'density': 38.9},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '063',
#   'province_name': 'Colchagua',
#   'county': '06308',
#   'county_name': 'Placilla',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 4611,
#   'female_pop': 4553,
#   'total_pop': 9164,
#   'area': 146.9,
#   'density': 59.5},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '063',
#   'province_name': 'Colchagua',
#   'county': '06309',
#   'county_name': 'Pumanque',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 1789,
#   'female_pop': 1742,
#   'total_pop': 3531,
#   'area': 441,
#   'density': 7.8},
#  {'state': '06',
#   'state_name': "Libertador General Bernardo O'Higgins",
#   'province': '063',
#   'province_name': 'Colchagua',
#   'county': '06310',
#   'county_name': 'Santa Cruz',
#   'ss': '061',
#   'ss_name': 'Servicio de Salud O´Higgins',
#   'male_pop': 20458,
#   'female_pop': 20638,
#   'total_pop': 41096,
#   'area': 419.5,
#   'density': 90.2},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '071',
#   'province_name': 'Talca',
#   'county': '07101',
#   'county_name': 'Talca',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 115281,
#   'female_pop': 121443,
#   'total_pop': 236724,
#   'area': 232,
#   'density': 949.8},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '071',
#   'province_name': 'Talca',
#   'county': '07102',
#   'county_name': 'Constitución',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 24969,
#   'female_pop': 25379,
#   'total_pop': 50348,
#   'area': 1344,
#   'density': 34.3},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '071',
#   'province_name': 'Talca',
#   'county': '07103',
#   'county_name': 'Curepto',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 4723,
#   'female_pop': 4703,
#   'total_pop': 9426,
#   'area': 1073.8,
#   'density': 8.8},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '071',
#   'province_name': 'Talca',
#   'county': '07104',
#   'county_name': 'Empedrado',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 2130,
#   'female_pop': 2076,
#   'total_pop': 4206,
#   'area': 565,
#   'density': 7.3},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '071',
#   'province_name': 'Talca',
#   'county': '07105',
#   'county_name': 'Maule',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 29401,
#   'female_pop': 30599,
#   'total_pop': 60000,
#   'area': 190,
#   'density': 261.7},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '071',
#   'province_name': 'Talca',
#   'county': '07106',
#   'county_name': 'Pelarco',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 4515,
#   'female_pop': 4568,
#   'total_pop': 9083,
#   'area': 332,
#   'density': 25.4},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '071',
#   'province_name': 'Talca',
#   'county': '07107',
#   'county_name': 'Pencahue',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 4308,
#   'female_pop': 4293,
#   'total_pop': 8601,
#   'area': 956.8,
#   'density': 8.6},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '071',
#   'province_name': 'Talca',
#   'county': '07108',
#   'county_name': 'Río Claro',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 7418,
#   'female_pop': 7335,
#   'total_pop': 14753,
#   'area': 431,
#   'density': 32.3},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '071',
#   'province_name': 'Talca',
#   'county': '07109',
#   'county_name': 'San Clemente',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 22916,
#   'female_pop': 23376,
#   'total_pop': 46292,
#   'area': 4504,
#   'density': 9.6},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '071',
#   'province_name': 'Talca',
#   'county': '07110',
#   'county_name': 'San Rafael',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 4940,
#   'female_pop': 5019,
#   'total_pop': 9959,
#   'area': 263.5,
#   'density': 34.9},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '072',
#   'province_name': 'Cauquenes',
#   'county': '07201',
#   'county_name': 'Cauquenes',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 21500,
#   'female_pop': 22643,
#   'total_pop': 44143,
#   'area': 2216,
#   'density': 18.3},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '072',
#   'province_name': 'Cauquenes',
#   'county': '07202',
#   'county_name': 'Chanco',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 4622,
#   'female_pop': 4709,
#   'total_pop': 9331,
#   'area': 530,
#   'density': 16.9},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '072',
#   'province_name': 'Cauquenes',
#   'county': '07203',
#   'county_name': 'Pelluhue',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 3999,
#   'female_pop': 4093,
#   'total_pop': 8092,
#   'area': 371,
#   'density': 20.4},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '073',
#   'province_name': 'Curicó',
#   'county': '07301',
#   'county_name': 'Curicó',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 80298,
#   'female_pop': 83328,
#   'total_pop': 163626,
#   'area': 1328,
#   'density': 112.3},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '073',
#   'province_name': 'Curicó',
#   'county': '07302',
#   'county_name': 'Hualañé',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 5091,
#   'female_pop': 5131,
#   'total_pop': 10222,
#   'area': 629,
#   'density': 15.4},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '073',
#   'province_name': 'Curicó',
#   'county': '07303',
#   'county_name': 'Licantén',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 3479,
#   'female_pop': 3510,
#   'total_pop': 6989,
#   'area': 273,
#   'density': 24.4},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '073',
#   'province_name': 'Curicó',
#   'county': '07304',
#   'county_name': 'Molina',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 24496,
#   'female_pop': 25304,
#   'total_pop': 49800,
#   'area': 1552,
#   'density': 29.6},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '073',
#   'province_name': 'Curicó',
#   'county': '07305',
#   'county_name': 'Rauco',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 5570,
#   'female_pop': 5678,
#   'total_pop': 11248,
#   'area': 309,
#   'density': 33.9},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '073',
#   'province_name': 'Curicó',
#   'county': '07306',
#   'county_name': 'Romeral',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 7989,
#   'female_pop': 8181,
#   'total_pop': 16170,
#   'area': 1597,
#   'density': 9.5},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '073',
#   'province_name': 'Curicó',
#   'county': '07307',
#   'county_name': 'Sagrada Familia',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 9691,
#   'female_pop': 9778,
#   'total_pop': 19469,
#   'area': 548.8,
#   'density': 33.8},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '073',
#   'province_name': 'Curicó',
#   'county': '07308',
#   'county_name': 'Teno',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 15391,
#   'female_pop': 15459,
#   'total_pop': 30850,
#   'area': 618.4,
#   'density': 46.8},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '073',
#   'province_name': 'Curicó',
#   'county': '07309',
#   'county_name': 'Vichuquén',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 2188,
#   'female_pop': 2193,
#   'total_pop': 4381,
#   'area': 426,
#   'density': 10.2},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '074',
#   'province_name': 'Linares',
#   'county': '07401',
#   'county_name': 'Linares',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 49120,
#   'female_pop': 51953,
#   'total_pop': 101073,
#   'area': 1466,
#   'density': 63.9},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '074',
#   'province_name': 'Linares',
#   'county': '07402',
#   'county_name': 'Colbún',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 11125,
#   'female_pop': 11440,
#   'total_pop': 22565,
#   'area': 2899.9,
#   'density': 7.2},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '074',
#   'province_name': 'Linares',
#   'county': '07403',
#   'county_name': 'Longaví',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 16377,
#   'female_pop': 16433,
#   'total_pop': 32810,
#   'area': 1454,
#   'density': 21},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '074',
#   'province_name': 'Linares',
#   'county': '07404',
#   'county_name': 'Parral',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 21797,
#   'female_pop': 22747,
#   'total_pop': 44544,
#   'area': 1638,
#   'density': 25.4},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '074',
#   'province_name': 'Linares',
#   'county': '07405',
#   'county_name': 'Retiro',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 10464,
#   'female_pop': 10607,
#   'total_pop': 21071,
#   'area': 827,
#   'density': 24.2},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '074',
#   'province_name': 'Linares',
#   'county': '07406',
#   'county_name': 'San Javier',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 24189,
#   'female_pop': 25262,
#   'total_pop': 49451,
#   'area': 1313,
#   'density': 34.7},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '074',
#   'province_name': 'Linares',
#   'county': '07407',
#   'county_name': 'Villa Alegre',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 8562,
#   'female_pop': 8950,
#   'total_pop': 17512,
#   'area': 190,
#   'density': 85.4},
#  {'state': '07',
#   'state_name': 'Maule',
#   'province': '074',
#   'province_name': 'Linares',
#   'county': '07408',
#   'county_name': 'Yerbas Buenas',
#   'ss': '071',
#   'ss_name': 'Servicio de Salud del Maule',
#   'male_pop': 9551,
#   'female_pop': 9649,
#   'total_pop': 19200,
#   'area': 262,
#   'density': 69},
#  {'state': '08',
#   'state_name': 'Biobío',
#   'province': '081',
#   'province_name': 'Concepción',
#   'county': '08101',
#   'county_name': 'Concepción',
#   'ss': '083',
#   'ss_name': 'Servicio de Salud Concepción',
#   'male_pop': 116039,
#   'female_pop': 122053,
#   'total_pop': 238092,
#   'area': 221.6,
#   'density': 1008.9},
#  {'state': '08',
#   'state_name': 'Biobío',
#   'province': '081',
#   'province_name': 'Concepción',
#   'county': '08102',
#   'county_name': 'Coronel',
#   'ss': '083',
#   'ss_name': 'Servicio de Salud Concepción',
#   'male_pop': 61168,
#   'female_pop': 64661,
#   'total_pop': 125829,
#   'area': 279.4,
#   'density': 416.1},
#  {'state': '08',
#   'state_name': 'Biobío',
#   'province': '081',
#   'province_name': 'Concepción',
#   'county': '08103',
#   'county_name': 'Chiguayante',
#   'ss': '083',
#   'ss_name': 'Servicio de Salud Concepción',
#   'male_pop': 44128,
#   'female_pop': 47052,
#   'total_pop': 91180,
#   'area': 71.5,
#   'density': 1201.9},
#  {'state': '08',
#   'state_name': 'Biobío',
#   'province': '081',
#   'province_name': 'Concepción',
#   'county': '08104',
#   'county_name': 'Florida',
#   'ss': '083',
#   'ss_name': 'Servicio de Salud Concepción',
#   'male_pop': 5850,
#   'female_pop': 5991,
#   'total_pop': 11841,
#   'area': 608.6,
#   'density': 17.5},
#  {'state': '08',
#   'state_name': 'Biobío',
#   'province': '081',
#   'province_name': 'Concepción',
#   'county': '08105',
#   'county_name': 'Hualqui',
#   'ss': '083',
#   'ss_name': 'Servicio de Salud Concepción',
#   'male_pop': 12746,
#   'female_pop': 13455,
#   'total_pop': 26201,
#   'area': 530.5,
#   'density': 589.2},
#  {'state': '08',
#   'state_name': 'Biobío',
#   'province': '081',
#   'province_name': 'Concepción',
#   'county': '08106',
#   'county_name': 'Lota',
#   'ss': '083',
#   'ss_name': 'Servicio de Salud Concepción',
#   'male_pop': 22331,
#   'female_pop': 23419,
#   'total_pop': 45750,
#   'area': 135.8,
#   'density': 320.6},
#  {'state': '08',
#   'state_name': 'Biobío',
#   'province': '081',
#   'province_name': 'Concepción',
#   'county': '08107',
#   'county_name': 'Penco',
#   'ss': '084',
#   'ss_name': 'Servicio de Salud Talcahuano',
#   'male_pop': 24228,
#   'female_pop': 25637,
#   'total_pop': 49865,
#   'area': 107.6,
#   'density': 440.2},
#  {'state': '08',
#   'state_name': 'Biobío',
#   'province': '081',
#   'province_name': 'Concepción',
#   'county': '08108',
#   'county_name': 'San Pedro de la Paz',
#   'ss': '083',
#   'ss_name': 'Servicio de Salud Concepción',
#   'male_pop': 70744,
#   'female_pop': 75162,
#   'total_pop': 145906,
#   'area': 112.5,
#   'density': 1171.6},
#  {'state': '08',
#   'state_name': 'Biobío',
#   'province': '081',
#   'province_name': 'Concepción',
#   'county': '08109',
#   'county_name': 'Santa Juana',
#   'ss': '083',
#   'ss_name': 'Servicio de Salud Concepción',
#   'male_pop': 7246,
#   'female_pop': 7533,
#   'total_pop': 14779,
#   'area': 731.2,
#   'density': 18.8},
#  {'state': '08',
#   'state_name': 'Biobío',
#   'province': '081',
#   'province_name': 'Concepción',
#   'county': '08110',
#   'county_name': 'Talcahuano',
#   'ss': '084',
#   'ss_name': 'Servicio de Salud Talcahuano',
#   'male_pop': 77112,
#   'female_pop': 81233,
#   'total_pop': 158345,
#   'area': 92.3,
#   'density': 1644.1},
#  {'state': '08',
#   'state_name': 'Biobío',
#   'province': '081',
#   'province_name': 'Concepción',
#   'county': '08111',
#   'county_name': 'Tomé',
#   'ss': '084',
#   'ss_name': 'Servicio de Salud Talcahuano',
#   'male_pop': 28466,
#   'female_pop': 30263,
#   'total_pop': 58729,
#   'area': 494.5,
#   'density': 111.1},
#  {'state': '08',
#   'state_name': 'Biobío',
# ...
#   'total_pop': 21477,
#   'area': 653,
#   'density': 29.6},
#  {'state': '13',
#   'state_name': 'Metropolitana de Santiago',
#   'province': '134',
#   'province_name': 'Maipo',
#   'county': '13401',
#   'county_name': 'San Bernardo',
#   'ss': '135',
#   'ss_name': 'Servicio de Salud Metropolitano Sur',
#   'male_pop': 165636,
#   'female_pop': 169200,
#   'total_pop': 334836,
#   'area': 155,
#   'density': 1943.9},
#  {'state': '13',
#   'state_name': 'Metropolitana de Santiago',
#   'province': '134',
#   'province_name': 'Maipo',
#   'county': '13402',
#   'county_name': 'Buin',
#   'ss': '135',
#   'ss_name': 'Servicio de Salud Metropolitano Sur',
#   'male_pop': 54264,
#   'female_pop': 55377,
#   'total_pop': 109641,
#   'area': 214,
#   'density': 451.5},
#  {'state': '13',
#   'state_name': 'Metropolitana de Santiago',
#   'province': '134',
#   'province_name': 'Maipo',
#   'county': '13403',
#   'county_name': 'Calera de Tango',
#   'ss': '135',
#   'ss_name': 'Servicio de Salud Metropolitano Sur',
#   'male_pop': 14178,
#   'female_pop': 14347,
#   'total_pop': 28525,
#   'area': 73.3,
#   'density': 346.4},
#  {'state': '13',
#   'state_name': 'Metropolitana de Santiago',
#   'province': '134',
#   'province_name': 'Maipo',
#   'county': '13404',
#   'county_name': 'Paine',
#   'ss': '135',
#   'ss_name': 'Servicio de Salud Metropolitano Sur',
#   'male_pop': 41201,
#   'female_pop': 41565,
#   'total_pop': 82766,
#   'area': 820,
#   'density': 88.7},
#  {'state': '13',
#   'state_name': 'Metropolitana de Santiago',
#   'province': '135',
#   'province_name': 'Melipilla',
#   'county': '13501',
#   'county_name': 'Melipilla',
#   'ss': '133',
#   'ss_name': 'Servicio de Salud Metropolitano Occidente',
#   'male_pop': 70347,
#   'female_pop': 71265,
#   'total_pop': 141612,
#   'area': 1345,
#   'density': 91.9},
#  {'state': '13',
#   'state_name': 'Metropolitana de Santiago',
#   'province': '135',
#   'province_name': 'Melipilla',
#   'county': '13502',
#   'county_name': 'Alhué',
#   'ss': '133',
#   'ss_name': 'Servicio de Salud Metropolitano Occidente',
#   'male_pop': 3733,
#   'female_pop': 3672,
#   'total_pop': 7405,
#   'area': 845,
#   'density': 7.6},
#  {'state': '13',
#   'state_name': 'Metropolitana de Santiago',
#   'province': '135',
#   'province_name': 'Melipilla',
#   'county': '13503',
#   'county_name': 'Curacaví',
#   'ss': '133',
#   'ss_name': 'Servicio de Salud Metropolitano Occidente',
#   'male_pop': 18079,
#   'female_pop': 18351,
#   'total_pop': 36430,
#   'area': 693,
#   'density': 47},
#  {'state': '13',
#   'state_name': 'Metropolitana de Santiago',
#   'province': '135',
#   'province_name': 'Melipilla',
#   'county': '13504',
#   'county_name': 'María Pinto',
#   'ss': '133',
#   'ss_name': 'Servicio de Salud Metropolitano Occidente',
#   'male_pop': 7402,
#   'female_pop': 7524,
#   'total_pop': 14926,
#   'area': 393.5,
#   'density': 34.5},
#  {'state': '13',
#   'state_name': 'Metropolitana de Santiago',
#   'province': '135',
#   'province_name': 'Melipilla',
#   'county': '13505',
#   'county_name': 'San Pedro',
#   'ss': '133',
#   'ss_name': 'Servicio de Salud Metropolitano Occidente',
#   'male_pop': 6031,
#   'female_pop': 5922,
#   'total_pop': 11953,
#   'area': 788,
#   'density': 12.3},
#  {'state': '13',
#   'state_name': 'Metropolitana de Santiago',
#   'province': '136',
#   'province_name': 'Talagante',
#   'county': '13601',
#   'county_name': 'Talagante',
#   'ss': '133',
#   'ss_name': 'Servicio de Salud Metropolitano Occidente',
#   'male_pop': 40453,
#   'female_pop': 41385,
#   'total_pop': 81838,
#   'area': 126,
#   'density': 589.2},
#  {'state': '13',
#   'state_name': 'Metropolitana de Santiago',
#   'province': '136',
#   'province_name': 'Talagante',
#   'county': '13602',
#   'county_name': 'El Monte',
#   'ss': '133',
#   'ss_name': 'Servicio de Salud Metropolitano Occidente',
#   'male_pop': 19798,
#   'female_pop': 20216,
#   'total_pop': 40014,
#   'area': 118,
#   'density': 304.4},
#  {'state': '13',
#   'state_name': 'Metropolitana de Santiago',
#   'province': '136',
#   'province_name': 'Talagante',
#   'county': '13603',
#   'county_name': 'Isla de Maipo',
#   'ss': '133',
#   'ss_name': 'Servicio de Salud Metropolitano Occidente',
#   'male_pop': 19914,
#   'female_pop': 20257,
#   'total_pop': 40171,
#   'area': 189,
#   'density': 191.6},
#  {'state': '13',
#   'state_name': 'Metropolitana de Santiago',
#   'province': '136',
#   'province_name': 'Talagante',
#   'county': '13604',
#   'county_name': 'Padre Hurtado',
#   'ss': '133',
#   'ss_name': 'Servicio de Salud Metropolitano Occidente',
#   'male_pop': 36769,
#   'female_pop': 37419,
#   'total_pop': 74188,
#   'area': 80.8,
#   'density': 782.8},
#  {'state': '13',
#   'state_name': 'Metropolitana de Santiago',
#   'province': '136',
#   'province_name': 'Talagante',
#   'county': '13605',
#   'county_name': 'Peñaflor',
#   'ss': '133',
#   'ss_name': 'Servicio de Salud Metropolitano Occidente',
#   'male_pop': 49844,
#   'female_pop': 51214,
#   'total_pop': 101058,
#   'area': 69,
#   'density': 1307.3},
#  {'state': '14',
#   'state_name': 'Los Ríos',
#   'province': '141',
#   'province_name': 'Valdivia',
#   'county': '14101',
#   'county_name': 'Valdivia',
#   'ss': '141',
#   'ss_name': 'Servicio de Salud Valdivia',
#   'male_pop': 85976,
#   'female_pop': 90798,
#   'total_pop': 176774,
#   'area': 1016,
#   'density': 163.5},
#  {'state': '14',
#   'state_name': 'Los Ríos',
#   'province': '141',
#   'province_name': 'Valdivia',
#   'county': '14102',
#   'county_name': 'Corral',
#   'ss': '141',
#   'ss_name': 'Servicio de Salud Valdivia',
#   'male_pop': 2699,
#   'female_pop': 2748,
#   'total_pop': 5447,
#   'area': 767,
#   'density': 6.9},
#  {'state': '14',
#   'state_name': 'Los Ríos',
#   'province': '141',
#   'province_name': 'Valdivia',
#   'county': '14103',
#   'county_name': 'Lanco',
#   'ss': '141',
#   'ss_name': 'Servicio de Salud Valdivia',
#   'male_pop': 8653,
#   'female_pop': 8999,
#   'total_pop': 17652,
#   'area': 532.4,
#   'density': 31.5},
#  {'state': '14',
#   'state_name': 'Los Ríos',
#   'province': '141',
#   'province_name': 'Valdivia',
#   'county': '14104',
#   'county_name': 'Los Lagos',
#   'ss': '141',
#   'ss_name': 'Servicio de Salud Valdivia',
#   'male_pop': 10152,
#   'female_pop': 10366,
#   'total_pop': 20518,
#   'area': 1791.2,
#   'density': 11},
#  {'state': '14',
#   'state_name': 'Los Ríos',
#   'province': '141',
#   'province_name': 'Valdivia',
#   'county': '14105',
#   'county_name': 'Máfil',
#   'ss': '141',
#   'ss_name': 'Servicio de Salud Valdivia',
#   'male_pop': 3637,
#   'female_pop': 3752,
#   'total_pop': 7389,
#   'area': 583,
#   'density': 12.2},
#  {'state': '14',
#   'state_name': 'Los Ríos',
#   'province': '141',
#   'province_name': 'Valdivia',
#   'county': '14106',
#   'county_name': 'Mariquina',
#   'ss': '141',
#   'ss_name': 'Servicio de Salud Valdivia',
#   'male_pop': 11475,
#   'female_pop': 11775,
#   'total_pop': 23250,
#   'area': 1320.5,
#   'density': 16.1},
#  {'state': '14',
#   'state_name': 'Los Ríos',
#   'province': '141',
#   'province_name': 'Valdivia',
#   'county': '14107',
#   'county_name': 'Paillaco',
#   'ss': '141',
#   'ss_name': 'Servicio de Salud Valdivia',
#   'male_pop': 10223,
#   'female_pop': 10575,
#   'total_pop': 20798,
#   'area': 896,
#   'density': 22.5},
#  {'state': '14',
#   'state_name': 'Los Ríos',
#   'province': '141',
#   'province_name': 'Valdivia',
#   'county': '14108',
#   'county_name': 'Panguipulli',
#   'ss': '141',
#   'ss_name': 'Servicio de Salud Valdivia',
#   'male_pop': 17786,
#   'female_pop': 18205,
#   'total_pop': 35991,
#   'area': 3292,
#   'density': 10.5},
#  {'state': '14',
#   'state_name': 'Los Ríos',
#   'province': '142',
#   'province_name': 'Ranco',
#   'county': '14201',
#   'county_name': 'La Unión',
#   'ss': '141',
#   'ss_name': 'Servicio de Salud Valdivia',
#   'male_pop': 19419,
#   'female_pop': 20119,
#   'total_pop': 39538,
#   'area': 2137,
#   'density': 17.8},
#  {'state': '14',
#   'state_name': 'Los Ríos',
#   'province': '142',
#   'province_name': 'Ranco',
#   'county': '14202',
#   'county_name': 'Futrono',
#   'ss': '141',
#   'ss_name': 'Servicio de Salud Valdivia',
#   'male_pop': 7530,
#   'female_pop': 7731,
#   'total_pop': 15261,
#   'area': 2267.5,
#   'density': 6.5},
#  {'state': '14',
#   'state_name': 'Los Ríos',
#   'province': '142',
#   'province_name': 'Ranco',
#   'county': '14203',
#   'county_name': 'Lago Ranco',
#   'ss': '141',
#   'ss_name': 'Servicio de Salud Valdivia',
#   'male_pop': 5140,
#   'female_pop': 5152,
#   'total_pop': 10292,
#   'area': 1763.3,
#   'density': 5.6},
#  {'state': '14',
#   'state_name': 'Los Ríos',
#   'province': '142',
#   'province_name': 'Ranco',
#   'county': '14204',
#   'county_name': 'Río Bueno',
#   'ss': '141',
#   'ss_name': 'Servicio de Salud Valdivia',
#   'male_pop': 16225,
#   'female_pop': 16700,
#   'total_pop': 32925,
#   'area': 2211.7,
#   'density': 14.2},
#  {'state': '15',
#   'state_name': 'Arica y Parinacota',
#   'province': '151',
#   'province_name': 'Arica',
#   'county': '15101',
#   'county_name': 'Arica',
#   'ss': '151',
#   'ss_name': 'Servicio de Salud Arica',
#   'male_pop': 124220,
#   'female_pop': 123332,
#   'total_pop': 247552,
#   'area': 4799.4,
#   'density': 0.5},
#  {'state': '15',
#   'state_name': 'Arica y Parinacota',
#   'province': '151',
#   'province_name': 'Arica',
#   'county': '15102',
#   'county_name': 'Camarones',
#   'ss': '151',
#   'ss_name': 'Servicio de Salud Arica',
#   'male_pop': 634,
#   'female_pop': 599,
#   'total_pop': 1233,
#   'area': 3927,
#   'density': 0.3},
#  {'state': '15',
#   'state_name': 'Arica y Parinacota',
#   'province': '152',
#   'province_name': 'Parinacota',
#   'county': '15201',
#   'county_name': 'Putre',
#   'ss': '151',
#   'ss_name': 'Servicio de Salud Arica',
#   'male_pop': 1457,
#   'female_pop': 1058,
#   'total_pop': 2515,
#   'area': 5902.5,
#   'density': 0.5},
#  {'state': '15',
#   'state_name': 'Arica y Parinacota',
#   'province': '152',
#   'province_name': 'Parinacota',
#   'county': '15202',
#   'county_name': 'General Lagos',
#   'ss': '151',
#   'ss_name': 'Servicio de Salud Arica',
#   'male_pop': 433,
#   'female_pop': 377,
#   'total_pop': 810,
#   'area': 2244.4,
#   'density': 0.3},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '161',
#   'province_name': 'Diguillín',
#   'county': '16101',
#   'county_name': 'Chillán',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 95112,
#   'female_pop': 103512,
#   'total_pop': 198624,
#   'area': 511.2,
#   'density': 361.4},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '161',
#   'province_name': 'Diguillín',
#   'county': '16102',
#   'county_name': 'Bulnes',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 10983,
#   'female_pop': 11624,
#   'total_pop': 22607,
#   'area': 425.4,
#   'density': 50.5},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '161',
#   'province_name': 'Diguillín',
#   'county': '16103',
#   'county_name': 'Chillán Viejo',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 16221,
#   'female_pop': 17606,
#   'total_pop': 33827,
#   'area': 291.8,
#   'density': 105.9},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '161',
#   'province_name': 'Diguillín',
#   'county': '16104',
#   'county_name': 'El Carmen',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 6059,
#   'female_pop': 6275,
#   'total_pop': 12334,
#   'area': 664.3,
#   'density': 18.1},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '161',
#   'province_name': 'Diguillín',
#   'county': '16105',
#   'county_name': 'Pemuco',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 4261,
#   'female_pop': 4378,
#   'total_pop': 8639,
#   'area': 562.7,
#   'density': 15},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '161',
#   'province_name': 'Diguillín',
#   'county': '16106',
#   'county_name': 'Pinto',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 5805,
#   'female_pop': 6075,
#   'total_pop': 11880,
#   'area': 1164,
#   'density': 9.3},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '161',
#   'province_name': 'Diguillín',
#   'county': '16107',
#   'county_name': 'Quillón',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 9192,
#   'female_pop': 9585,
#   'total_pop': 18777,
#   'area': 423,
#   'density': 41.3},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '161',
#   'province_name': 'Diguillín',
#   'county': '16108',
#   'county_name': 'San Ignacio',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 8130,
#   'female_pop': 8494,
#   'total_pop': 16624,
#   'area': 363.6,
#   'density': 44.2},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '161',
#   'province_name': 'Diguillín',
#   'county': '16109',
#   'county_name': 'Yungay',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 9156,
#   'female_pop': 9440,
#   'total_pop': 18596,
#   'area': 823.5,
#   'density': 21.6},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '162',
#   'province_name': 'Itata',
#   'county': '16201',
#   'county_name': 'Quirihue',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 5950,
#   'female_pop': 6242,
#   'total_pop': 12192,
#   'area': 589,
#   'density': 19.7},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '162',
#   'province_name': 'Itata',
#   'county': '16202',
#   'county_name': 'Cobquecura',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 2588,
#   'female_pop': 2687,
#   'total_pop': 5275,
#   'area': 570.3,
#   'density': 8.8},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '162',
#   'province_name': 'Itata',
#   'county': '16203',
#   'county_name': 'Coelemu',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 8252,
#   'female_pop': 8593,
#   'total_pop': 16845,
#   'area': 342.3,
#   'density': 46.7},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '162',
#   'province_name': 'Itata',
#   'county': '16204',
#   'county_name': 'Ninhue',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 2650,
#   'female_pop': 2764,
#   'total_pop': 5414,
#   'area': 401.2,
#   'density': 13},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '162',
#   'province_name': 'Itata',
#   'county': '16205',
#   'county_name': 'Portezuelo',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 2421,
#   'female_pop': 2519,
#   'total_pop': 4940,
#   'area': 282.3,
#   'density': 17.2},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '162',
#   'province_name': 'Itata',
#   'county': '16206',
#   'county_name': 'Ránquil',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 3060,
#   'female_pop': 3201,
#   'total_pop': 6261,
#   'area': 248.3,
#   'density': 23.2},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '162',
#   'province_name': 'Itata',
#   'county': '16207',
#   'county_name': 'Treguaco',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 2811,
#   'female_pop': 2885,
#   'total_pop': 5696,
#   'area': 313.1,
#   'density': 17.3},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '163',
#   'province_name': 'Punilla',
#   'county': '16301',
#   'county_name': 'San Carlos',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 27234,
#   'female_pop': 29018,
#   'total_pop': 56252,
#   'area': 874,
#   'density': 60.7},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '163',
#   'province_name': 'Punilla',
#   'county': '16302',
#   'county_name': 'Coihueco',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 13920,
#   'female_pop': 14455,
#   'total_pop': 28375,
#   'area': 1776.6,
#   'density': 15.1},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '163',
#   'province_name': 'Punilla',
#   'county': '16303',
#   'county_name': 'Ñiquén',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 5734,
#   'female_pop': 5833,
#   'total_pop': 11567,
#   'area': 493.1,
#   'density': 22.6},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '163',
#   'province_name': 'Punilla',
#   'county': '16304',
#   'county_name': 'San Fabián',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 2287,
#   'female_pop': 2367,
#   'total_pop': 4654,
#   'area': 1568.3,
#   'density': 2.8},
#  {'state': '16',
#   'state_name': 'Ñuble',
#   'province': '163',
#   'province_name': 'Punilla',
#   'county': '16305',
#   'county_name': 'San Nicolás',
#   'ss': '161',
#   'ss_name': 'Servicio de Salud Ñuble',
#   'male_pop': 5966,
#   'female_pop': 6206,
#   'total_pop': 12172,
#   'area': 490.5,
#   'density': 23.7}]

# %%
print('Importing data from all regions')
tstate = ['01','02','03','04','05','06','07','08','09','10','11','12','13','14','15','16']
#tstate = '13101'
# Import Data
state = ImportData(tstate=tstate,initdate = initdate)
state.importdata()

state.importDailyInfectedNacional()
state.name = 'Chile'

# %% [markdown]
# ### Datos de Hospitalizados a fitear

# %%
state.Hr = 1000
state.Hr_tot = [10000,10000]
state.Vr = state.UCI_use_covid
state.Vr_tot = [4000]*len(state.UCI_use_covid)#state.UCI_capacity
state.UCI_non_covid = state.UCI_use_noncovid
state.sochimi_tr = state.UCI_tr#[-2:]
state.sochimi_dates = state.UCI_dates

# %% [markdown]
# ## Infectados Diarios

# %%
endpoint = 'https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/output/producto5/TotalesNacionales.csv'
casosnuevos = pd.read_csv(endpoint)
I_d = casosnuevos[casosnuevos['Fecha']=='Casos nuevos totales'].transpose()
dates_I_d = [timetxttoDatetime(I_d.axes[0][i]) for i in range(1,len(I_d.axes[0]))]
I_d = np.array(I_d.iloc[1:][6])
I_ac = np.cumsum(I_d)

index_ac = np.where(np.array(dates_I_d) >= initdate)[0][0]
I_ac = I_ac[index_ac:]
I_ac_dates = dates_I_d[index_ac:]
I_ac_tr = [(i-initdate).days for i in I_ac_dates]

index = np.where(np.array(dates_I_d) >= initdate-timedelta(days=7))[0][0]
dates_I_d = dates_I_d[index:]
I_d = I_d[index:]
weekdays = [date.weekday(dates_I_d[i]) for i in range(len(dates_I_d))]
I = pd.DataFrame({'dates':dates_I_d,'I':I_d,'weekdays':weekdays})
I_week = I[(I['weekdays']>2) | (I['weekdays']==0)]
I_week_ra = I_week['I'].rolling(5).mean()[I_week['dates']>=initdate]
I_week_ra_dates = I_week['dates'][I_week['dates']>=initdate]
I_week_ra_tr = [(i-initdate).days for i in I_week_ra_dates]
index_date = np.where(np.array(dates_I_d) >= initdate)[0][0]

# %%
initdate

# %% [markdown]
# ## Subreport

# %%
Imi_det = 0.4
Ias_det = 0.1
Ise_det = 1
Icr_det = 1

# %% [markdown]
# # Parameters Fiteo UCI

# %%
# Total simulation time
tsim = 1000

beta = 1
mu = 0.35#list(np.arange(0.2,0.4,0.01))#0.4
k_I = 0
k_R = 0#10
SeroPrevFactor = 0.6#1
expinfection=0 # Proportion in which the exposed infect - 0: nothing, 1: equally as Infected

# %%
state.population*0.2

# %% [markdown]
# # Quarantines

# %%
mob_dates = [initdate,datetime(2020,12,21),datetime(2021,1,8),datetime(2021,2,25),datetime(2021,3,19),datetime(2021,4,4),initdate+timedelta(days=tsim)]
mob_days = []
for i in range(len(mob_dates)-1):
    d1 = (mob_dates[i]-initdate).days
    d2 = (mob_dates[i+1]-initdate).days
    mob_days.append([d1,d2])

mobility = [0.0099,0.0126,0.0209,0.03,0.04]

escenarios = [0.03,0.035,0.04,0.045,0.05]
alpha_var = escenarios
alpha_new = [Events.Events(values=mobility +[i],days=mob_days) for i in escenarios]

# %% [markdown]
# # Parameters Fiteo EPI

# %%
# Total simulation time
tsim = 1000

beta = 1
mu = 0.356#list(np.arange(0.2,0.4,0.01))#0.4
k_I = 0
k_R = 0#10
SeroPrevFactor = 0.6#1
expinfection=0 # Proportion in which the exposed infect - 0: nothing, 1: equally as Infected

# %%
state.population*0.2

# %% [markdown]
# # Quarantines

# %%
mob_dates = [initdate,datetime(2020,12,25),datetime(2021,1,23),datetime(2021,2,17),datetime(2021,3,19),datetime(2021,4,4),initdate+timedelta(days=tsim)]
mob_days = []
for i in range(len(mob_dates)-1):
    d1 = (mob_dates[i]-initdate).days
    d2 = (mob_dates[i+1]-initdate).days
    mob_days.append([d1,d2])

mobility = [0.01,0.012,0.005,0.03,0.04]

escenarios = [0.03,0.035,0.04,0.045,0.05]
alpha_var = escenarios
alpha_new = [Events.Events(values=mobility +[i],days=mob_days) for i in escenarios]

# %%
if False:
    datelinewidth = 1
    t = np.array(np.arange(0,240,0.1))
    alphaplot= [[j(i) for i in t] for j in alpha_new]
    for f in alphaplot:
        plt.plot(t,f)
    #for f in alphaplot_UK:
        #plt.plot(t,f,linestyle='dashed') 
    plt.axvline(x = navidad_day, linestyle = 'dotted',color = 'red',label='Navidad',linewidth=datelinewidth)
    plt.axvline(x = newyear_day, linestyle = 'dotted',color = 'blue',label='Año Nuevo',linewidth=datelinewidth)
    #plt.axvline(x = mitadvacaciones_day, linestyle = 'dotted',color = 'green',label='15 Febrero',linewidth=datelinewidth)

    plt.tick_params(labelsize=18)
    plt.legend(loc=0)
    plt.title('Mobility-beta',fontsize=20)
    plt.show()

# %% [markdown]
# ## SeroPrevalence Dynamics
# The susceptibles increase through a step function which last for the specified amount of days. Throughout these days it adds a "dailyincrease" amount of persons each day.
#
# The total increase of people is increasedays*dailyincrease

# %%
def aux(t):
    return 0

chi = aux

# %% [markdown]
# #### Plot Susceptible Dynamics

# %% [markdown]
# # State transition parameters:

# %%
#state parameters: 
pE_Ias = 0.43 # Transition from exposed to Asymptomatic Infected
tE_Ias = 3.0
pE_Imi = 0.53 # Transition from exposed to  Mild Infected
tE_Imi = 3.0
pE_Icr = 0.0065 # Transition from exposed to  Critical Infected
tE_Icr = 3.0
pE_Ise = 0.0335# Transition from exposed to  Serious Infected
tE_Ise = 3.0
pIas_R = 1.0   # Transition from Asymptomatic Infected to Recovered
tIas_R = 5.0
pImi_R = 1.0  # Transition from Mild Infected to Recovered
tImi_R = 5.0
pIse_Hse = 1 # Transition from Serious Infected to Serious Hospitalized (When Hospital capacity is not saturated)
tIse_Hse = 5.0
pIse_D = 1.0  # Transition from Serious Infected to Death (When Hospital capacity is saturated)
tIse_D = 3.0
pIcr_V = 1.0  # Transition from Critical Infected to Ventilator (When Ventilators capacity is not saturated)
tIcr_V = 3.0
pIcr_D = 1.0  # Transition from Serious Infected to Death (When Ventilators capacity is saturated)
tIcr_D = 3.0
pHse_R = 0.97 # Transition from Serious Hospitalized to Recovered
tHse_R = 3.5
pHse_V = 0.03# Transition from Serious Hospitalized to Ventilators (When Ventilators capacity is not saturated)
tHse_V = 4.0
pHse_D = 0.85# Transition from Serious Hospitalized to Death (When Ventilators capacity is saturated)
tHse_D = 4.0
pV_Hout = 0.45  # Transition from Ventilators to Hospital Recovery (Hout)
tV_Hout = 16.0
pV_D = 0.55 # Transition from Ventilators to Death
tV_D = 12.0
pHout_R = 1.0 # Transition from Hospital Recovery (Hout) to Recovered
tHout_R = 10.0

# %% [markdown]
# # Simulation
#
# ## Initial SeroPrev period
# Initialize Simulation Object, set params and run the simulation.

# %%
mu

# %%
simulation = [SEIRHVD(tsim,beta,mu,alpha_new[i],k_I=k_I,k_R = k_R, chi = chi,                      
                      SeroPrevFactor=SeroPrevFactor,expinfection=expinfection,initdate = initdate,
                      Imi_det = Imi_det,Ias_det = Ias_det,RealIC=state) for i in range(len(alpha_new))]

# %% [markdown]
# Modify simulation state parameters

# %%
for i in range(len(simulation)):
    simulation[i].pE_Ias=pE_Ias
    simulation[i].tE_Ias=tE_Ias
    simulation[i].pE_Imi=pE_Imi
    simulation[i].tE_Imi=tE_Imi
    simulation[i].pE_Icr=pE_Icr
    simulation[i].tE_Icr=tE_Icr
    simulation[i].pE_Ise=pE_Ise
    simulation[i].tE_Ise=tE_Ise
    simulation[i].pIas_R=pIas_R
    simulation[i].tIas_R =tIas_R
    simulation[i].pImi_R=pImi_R
    simulation[i].tImi_R =tImi_R
    simulation[i].pIse_Hse=pIse_Hse
    simulation[i].tIse_Hse=tIse_Hse
    simulation[i].pIse_D=pIse_D
    simulation[i].tIse_D=tIse_D
    simulation[i].pIcr_V=pIcr_V
    simulation[i].tIcr_V=tIcr_V
    simulation[i].pIcr_D=pIcr_D
    simulation[i].tIcr_D=tIcr_D
    simulation[i].pHse_R=pHse_R
    simulation[i].tHse_R =tHse_R
    simulation[i].pHse_V=pHse_V
    simulation[i].tHse_V=tHse_V
    simulation[i].pHse_D=pHse_D
    simulation[i].tHse_D=tHse_D
    simulation[i].pV_Hout=pV_Hout
    simulation[i].tV_Hout =tV_Hout
    simulation[i].pV_D=pV_D
    simulation[i].tV_D =tV_D
    simulation[i].pHout_R=pHout_R
    simulation[i].tHout_R=tHout_R
    simulation[i].setnewparams()

# %% [markdown]
# ### Setting new params

# %% [markdown]
# ## Run simulation
#
# * **integr_sci**: Fast solver, sometimes stiffness beat it
# * **integr:** Slow solver, more robust with stiffness

# %%
def simulate(simulation,i,tsim):
    simulation[i].integr_sci(0,tsim,0.1)
    return simulation[i]

# %%
num_cores = multiprocessing.cpu_count()
sims = Parallel(n_jobs=num_cores, verbose=50)(delayed(simulate)(simulation,i,tsim) for i in range(len(simulation)))
simulation = sims
print('ready')

# %% [markdown]
# # Analysis

# %%
saveplot = False
if saveplot:
    # %matplotlib inline
#%matplotlib inline
# %matplotlib tk
# Big Screen
plt.rcParams["figure.figsize"] = 38.40, 20.56 #19.20,10.80#8,6
# Small Screen
#plt.rcParams["figure.figsize"] = 19.2, 10.80 #19.20,10.80#8,6
plt.rcParams.update({
    "text.usetex": False,
    "font.family": "sans-serif",
    "font.sans-serif":["Arial"]})

# %% [markdown]
# # Plot

# %%
# Days to plot
days = 500
t_end = 50

enddate = initdate + timedelta(days=365)
enddate = datetime(2021,9,30)


dates = [[initdate+timedelta(days=int(i)) for i in simulation[j].t] for j in range(len(simulation))]
SeroPrevalence = [simulation[i].I_ac[-1]/simulation[i].population for i in range(len(simulation))]
SeroPrevalenceDet = [simulation[i].I_ac_det[-1]/simulation[i].population for i in range(len(simulation))]

# %% [markdown]
# ### Pantalla

# %%
pantalla = '4k'
if pantalla == '4k':
    fontsize_title = 22
    fontsize_suptitle = 25
    fontsize_label = 18
    fontsize_legend = 14

#1080
elif pantalla == '1080':
    fontsize_title = 15
    fontsize_suptitle = 16
    fontsize_label = 12
    fontsize_legend = 8

pĺotlinewidth = 2
datelinewidth = 1.5

# %% [markdown]
# # Grid Plot

# %%
renewalFactor = [0]
sim_InfDiario = False
sim_InfEPI = True

colors = plt.cm.rainbow_r(np.linspace(0,1,len(simulation)))

fig, axs = plt.subplots(2, 2)

for i in range(len(simulation)):
    if type(mu) == list:
        axs[0,0].plot(dates[i],simulation[i].I_ac_det,linewidth=pĺotlinewidth,label='mu: '+str(mu[i])+' | SP_R: '+str(round(100*SeroPrevalence[i],2))+'%'+' | SP_D:'+str(round(100*SeroPrevalenceDet[i],2))+'%',color=colors[i])
    if type(alpha_new) == list:
        axs[0,0].plot(dates[i],simulation[i].I_ac_det,linewidth=pĺotlinewidth,label='beta: '+str(round(alpha_var[i],5))+' | SP_R: '+str(round(100*SeroPrevalence[i],2))+'%'+' | SP_D:'+str(round(100*SeroPrevalenceDet[i],2))+'%',color=colors[i])
axs[0,0].set_title('Infectados acumulados',fontsize=fontsize_title)
axs[0,0].set_xlim(initdate,enddate)
#axs[0,0].set_ylim(0,1.5e6)



axs[0,0].axvline(x = datetime(2020,12,25), linestyle = 'dotted',color = 'red',label='Navidad',linewidth=datelinewidth)
axs[0,0].axvline(x = datetime(2020,12,31), linestyle = 'dotted',color = 'blue',label='Año Nuevo',linewidth=datelinewidth)
#axs[0,0].axvline(x = datetime(2021,2,15), linestyle = 'dotted',color = 'green',label='15 Febrero',linewidth=datelinewidth)

 

#axs[0,0].plot([], [], ' ', label='RF: RenewalFactor')
#axs[0,0].plot([], [], ' ', label='SP_R: SeroPrevalence Real')
#axs[0,0].plot([], [], ' ', label='SP_D: SeroPrevalence Detected')

if sim_InfEPI:
    axs[0,0].scatter(state.I_ac_r_dates,state.I_ac_r,color='black',label='Informe EPI',zorder=10)

if sim_InfDiario:
    # cambiar
    axs[0,0].scatter(I_ac_dates,I_ac,color='grey',label='Informe Diario',zorder=10)

axs[0,0].fmt_xdata = mdates.DateFormatter('%Y-%m-%d')
axs[0,0].legend(loc=0)

axs[0,0].grid(color='grey', linestyle='dotted', linewidth=0.5)


# Accumulated deaths
for i in range(len(simulation)):
    if type(mu) == list:
        axs[0,1].plot(dates[i],simulation[i].B,label='mu: '+str(mu[i]),color=colors[i],linewidth=pĺotlinewidth)
    if type(alpha_new) == list:
        axs[0,1].plot(dates[i],simulation[i].B,label='beta: '+str(round(alpha_var[i],5)),color=colors[i],linewidth=pĺotlinewidth)
    
axs[0,1].set_title('Muertes Acumuladas',fontsize=fontsize_title)
axs[0,1].set_xlim(initdate,enddate)
#axs[0,1].set_ylim(0,1e4)

axs[0,1].axvline(x = datetime(2020,12,25), linestyle = 'dotted',color = 'red',label='Navidad',linewidth=datelinewidth)
axs[0,1].axvline(x = datetime(2020,12,31), linestyle = 'dotted',color = 'blue',label='Año Nuevo',linewidth=datelinewidth)
#axs[0,1].axvline(x = datetime(2021,2,15), linestyle = 'dotted',color = 'green',label='15 Febrero',linewidth=datelinewidth)

axs[0,1].scatter(state.Br_dates,state.Br,label='Datos',color='black',zorder=10)

axs[0,1].fmt_xdata = mdates.DateFormatter('%Y-%m-%d')
axs[0,1].legend(loc=0)


for i in range(len(simulation)):
    if type(mu) == list:
        axs[1,0].plot(dates[i],simulation[i].I_d_det,label='mu: '+str(mu[i]),color=colors[i],linewidth=pĺotlinewidth)
    if type(alpha_new) == list:
        axs[1,0].plot(dates[i],simulation[i].I_d_det,label='beta: '+str(round(alpha_var[i],5)),color=colors[i],linewidth=pĺotlinewidth)
axs[1,0].set_title('Nuevos Infectados Diarios',fontsize=fontsize_title)
axs[1,0].set_xlim(initdate,enddate)
#axs[1,0].set_ylim(0,1e4)

if sim_InfEPI:
    axs[1,0].scatter(state.I_d_r_dates,state.I_d_r,label='Informe EPI',color='black',zorder=5)
if sim_InfDiario:
    axs[1,0].scatter(I_week_ra_dates,I_week_ra,label='Informe diario (RA5D)',color='red',zorder=5)  
    axs[1,0].plot(dates_I_d,I_d,label='Informe diario',color='blue',zorder=10,linestyle='dashed')
    
#axs[1,0].axvline(x = SPchange_date, linestyle = 'dotted',color = 'grey',label='Inicio Apertura')
#axs[1,0].axvline(x = datetime(2020,8,22), linestyle = 'dotted',color = 'grey',label='Inicio Cuarentena')
#axs[1,0].axvline(x = fiestaspatrias, linestyle = 'dotted',color = 'red',label='18 Sept')
#axs[1,0].axvline(x = plebiscito, linestyle = 'dotted',color = 'blue',label='Plebiscito',linewidth=datelinewidth)

axs[1,0].axvline(x = datetime(2020,12,25), linestyle = 'dotted',color = 'red',label='Navidad',linewidth=datelinewidth)
axs[1,0].axvline(x = datetime(2020,12,31), linestyle = 'dotted',color = 'blue',label='Año Nuevo',linewidth=datelinewidth)
#axs[1,0].axvline(x = datetime(2021,2,15), linestyle = 'dotted',color = 'green',label='15 Febrero',linewidth=datelinewidth)

#axs[1,0].axvline(x = datetime(2020,7,18), linestyle = 'dotted',color = 'grey',label='Cambio a fase 3')
#axs[1,0].axvline(x = datetime(2020,9,11), linestyle = 'dashed',color = 'grey',label='Cambio a fase 4')
#axs[1,0].axvline(x = datetime(2020,10,3), linestyle = 'dashdot',color = 'grey',label='Cambio a fase 2')


axs[1,0].legend(loc=0)


for i in range(len(simulation)):
    if type(mu) == list:
        axs[1,1].plot(dates[i],simulation[i].V,label='mu: '+str(mu[i]),color=colors[i],linewidth=pĺotlinewidth)
    #axs[1,1].plot(dates[i],simulation[i].V_need,linestyle='dashed',color=colors[i])
    if type(alpha_new) == list:
        axs[1,1].plot(dates[i],simulation[i].V,label='beta: '+str(round(alpha_var[i],5)),color=colors[i],linewidth=pĺotlinewidth)
axs[1,1].set_title('Uso UCI',fontsize=fontsize_title)
axs[1,1].set_xlim(initdate,enddate)
#axs[1,1].set_ylim(0,3e3)

axs[1,1].scatter(state.UCI_dates,state.UCI_use_covid,label='Datos',color='black',zorder=10)
#axs[1,1].plot(state.UCI_dates,state.UCI_capacity,label='UCI Capacity', linestyle = 'dashed', color = 'grey')
axs[1,1].plot(simulation[0].dates,simulation[0].V_cap,label='UCI Capacity', linestyle = 'dashed', color = 'black')


#axs[1,1].axvline(x = fiestaspatrias, linestyle = 'dotted',color = 'red',label='18 Sept')
#axs[1,1].axvline(x = plebiscito, linestyle = 'dotted',color = 'blue',label='Plebiscito',linewidth=datelinewidth)
axs[1,1].axvline(x = datetime(2020,12,25), linestyle = 'dotted',color = 'red',label='Navidad',linewidth=datelinewidth)
axs[1,1].axvline(x = datetime(2020,12,31), linestyle = 'dotted',color = 'blue',label='Año Nuevo',linewidth=datelinewidth)
#axs[1,1].axvline(x = datetime(2021,2,15), linestyle = 'dotted',color = 'green',label='15 Febrero',linewidth=datelinewidth)



# Format and shit

# Grid
axs[0,0].grid(color='grey', linestyle='dotted', linewidth=0.5)
axs[0,1].grid(color='grey', linestyle='dotted', linewidth=0.5)
axs[1,0].grid(color='grey', linestyle='dotted', linewidth=0.5)
axs[1,1].grid(color='grey', linestyle='dotted', linewidth=0.5)


# Date format
axs[0,0].fmt_xdata = mdates.DateFormatter('%d-%m-%Y')
axs[0,1].fmt_xdata = mdates.DateFormatter('%d-%m-%Y')
axs[1,0].fmt_xdata = mdates.DateFormatter('%d-%m-%Y')
axs[1,1].fmt_xdata = mdates.DateFormatter('%d-%m-%Y')

# Y axis
#axs[0,0].get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
axs[0,1].get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
axs[1,0].get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
axs[1,1].get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

# Font-size
axs[0,0].tick_params(labelsize=fontsize_label)
axs[0,1].tick_params(labelsize=fontsize_label)
axs[1,0].tick_params(labelsize=fontsize_label)
axs[1,1].tick_params(labelsize=fontsize_label)

# Legend
axs[0,0].legend(loc=0,fontsize=fontsize_legend)
axs[0,1].legend(loc=1,fontsize=fontsize_legend)
axs[1,0].legend(loc=1,fontsize=fontsize_legend)
axs[1,1].legend(loc=1,fontsize=fontsize_legend)

# Ephemerides
for i in mob_dates:
    axs[0,0].axvline(x = i, linestyle = 'dashed',linewidth=datelinewidth)
    axs[0,1].axvline(x = i, linestyle = 'dashed',linewidth=datelinewidth)
    axs[1,0].axvline(x = i, linestyle = 'dashed',linewidth=datelinewidth)
    axs[1,1].axvline(x = i, linestyle = 'dashed',linewidth=datelinewidth)


fig.suptitle(state.name,fontsize=fontsize_suptitle)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-67bfd915d462> in <module>
#       3 sim_InfEPI = True
#       4
# ----> 5 colors = plt.cm.rainbow_r(np.linspace(0,1,len(simulation)))
#       6
#       7 fig, axs = plt.subplots(2, 2)
#
# NameError: name 'simulation' is not defined

# %%
len(alpha_var)

# %%
print('stop')

# %%
print('stop')
