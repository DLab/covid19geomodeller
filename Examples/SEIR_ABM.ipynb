# %%
import os
current_directory = os.getcwd()
parent_directory = os.path.dirname(current_directory)
os.chdir(parent_directory)

# %% [markdown]
# # Agent Based SEIR model example

# %%
import matplotlib.pyplot as plt

# %%
from cv19gm.models.seir_ABM import SEIR_ABM

#Input configuration file
config = 'Examples/cfg/SEIR_ABM.toml'

model = SEIR_ABM(config = config)
model.run()
# Out:
#   Activating project at `~/Recursos/DLAB/covid19geomodeller/covid19geomodeller/julia`

# %%
model.results
# Out:
#        I    R      S   E  I_d  R_d  S_d  E_d
# 0    101    0  99875  24    1    0    0   25
# 1    102    0  99871  27    1    0    0    4
# 2    100    4  99869  27    2    4    0    2
# 3     95   18  99866  21    9   14    0    3
# 4     59   55  99862  24    1   37    0    4
# ..   ...  ...    ...  ..  ...  ...  ...  ...
# 495    0  192  99808   0    0    0    0    0
# 496    0  192  99808   0    0    0    0    0
# 497    0  192  99808   0    0    0    0    0
# 498    0  192  99808   0    0    0    0    0
# 499    0  192  99808   0    0    0    0    0
#
# [500 rows x 8 columns]

# %%
model.daily
# Out:
#      I_d  R_d  S_d  E_d
# 0      1    0    0   25
# 1      1    0    0    4
# 2      2    4    0    2
# 3      9   14    0    3
# 4      1   37    0    4
# ..   ...  ...  ...  ...
# 495    0    0    0    0
# 496    0    0    0    0
# 497    0    0    0    0
# 498    0    0    0    0
# 499    0    0    0    0
#
# [500 rows x 4 columns]

# %%
model.totals
# Out:
#        I    R      S   E
# 0    101    0  99875  24
# 1    102    0  99871  27
# 2    100    4  99869  27
# 3     95   18  99866  21
# 4     59   55  99862  24
# ..   ...  ...    ...  ..
# 495    0  192  99808   0
# 496    0  192  99808   0
# 497    0  192  99808   0
# 498    0  192  99808   0
# 499    0  192  99808   0
#
# [500 rows x 4 columns]

# %%
plt.plot(model.S,label='S')
plt.plot(model.E,label='E')
plt.plot(model.I,label='I')
plt.plot(model.I_d,label='I_d')
plt.plot(model.R,label='R')
plt.legend(loc=0)
plt.show()

# %%
plt.plot(model.S_d,label='S_d')
plt.plot(model.E_d,label='E_d')
plt.plot(model.I_d,label='I_d')
plt.plot(model.R_d,label='R_d')
