# %%
import os
current_directory = os.getcwd()
parent_directory = os.path.dirname(current_directory)
os.chdir(parent_directory)

# %% [markdown]
# # Agent Based SEIR model example

# %%
import matplotlib.pyplot as plt

# %%
from cv19gm.models.seir_ABM import SEIR_ABM

#Input configuration file
config = 'Examples/cfg/SEIR_ABM.toml'

model = SEIR_ABM(config = config)
model.run()
# Out:
# Missing configuration file, using default
#   Activating project at `~/Recursos/DLAB/covid19geomodeller/covid19geomodeller/julia`

# %%
model.results
# Out:
#       I      R      S   E  I_d  R_d  S_d  E_d
# 0     4      0  99985  10    2    0    0    2
# 1     7      0  99984   8    3    0    0    1
# 2    10      0  99981   8    3    0    0    3
# 3    12      0  99979   8    2    0    0    2
# 4    13      0  99977   9    1    0    0    2
# ..   ..    ...    ...  ..  ...  ...  ...  ...
# 495   0  80329  19670   0    0    0    0    0
# 496   0  80329  19670   0    0    0    0    0
# 497   0  80329  19670   0    0    0    0    0
# 498   0  80329  19670   0    0    0    0    0
# 499   0  80329  19670   0    0    0    0    0
#
# [500 rows x 8 columns]

# %%
model.daily
# Out:
#      I_d  R_d  S_d  E_d
# 0      2    0    0    2
# 1      3    0    0    1
# 2      3    0    0    3
# 3      2    0    0    2
# 4      1    0    0    2
# ..   ...  ...  ...  ...
# 495    0    0    0    0
# 496    0    0    0    0
# 497    0    0    0    0
# 498    0    0    0    0
# 499    0    0    0    0
#
# [500 rows x 4 columns]

# %%
model.totals
# Out:
#       I      R      S   E
# 0     4      0  99985  10
# 1     7      0  99984   8
# 2    10      0  99981   8
# 3    12      0  99979   8
# 4    13      0  99977   9
# ..   ..    ...    ...  ..
# 495   0  80329  19670   0
# 496   0  80329  19670   0
# 497   0  80329  19670   0
# 498   0  80329  19670   0
# 499   0  80329  19670   0
#
# [500 rows x 4 columns]

# %%
plt.plot(model.S,label='S')
plt.plot(model.E,label='E')
plt.plot(model.I,label='I')
plt.plot(model.I_d,label='I_d')
plt.plot(model.R,label='R')
plt.xlim(0,300)
plt.legend(loc=0)
plt.show()

# %%
plt.plot(model.S_d,label='S_d')
plt.plot(model.E_d,label='E_d')
plt.plot(model.I_d,label='I_d')
plt.plot(model.R_d,label='R_d')
