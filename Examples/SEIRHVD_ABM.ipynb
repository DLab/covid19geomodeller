# %%
import os
current_directory = os.getcwd()
parent_directory = os.path.dirname(current_directory)
os.chdir(parent_directory)

# %% [markdown]
# # Agent Based SEIRHVD model example

# %%
import matplotlib.pyplot as plt

# %%
from cv19gm.models.seirhvd_ABM import SEIRHVD_ABM

#Input configuration file
config = 'Examples/cfg/SEIRHVD_ABM.toml'

model = SEIRHVD_ABM(config=config)
model.run()
# Out:
#   Activating project at `~/Recursos/DLAB/covid19geomodeller/covid19geomodeller/julia`

# %%
model.results
# Out:
#       Hv     Sv      S  R  Imv  H  Im  Rv    Dv    E  ...  Imv_d_d  H_d_d  \
# 0      0    100  99886  0   14  1  10   0     1  213  ...        4      1
# 1      0    199  99783  0   14  1  10   0     1  217  ...        0      0
# 2      0    298  99683  0   15  2  10   0     1  216  ...        1      1
# 3      0    397  99581  0   17  2  11   0     1  217  ...        2      0
# 4      0    496  99475  0   17  2  12   0     1  223  ...        0      0
# ...   ..    ...    ... ..  ... ..  ..  ..   ...  ...  ...      ...    ...
# 1495   0  55199  30344  0    0  0   0   0  3327    0  ...        0      0
# 1496   0  55232  30311  0    0  0   0   0  3327    0  ...        0      0
# 1497   0  55263  30280  0    0  0   0   0  3327    0  ...        0      0
# 1498   0  55295  30248  0    0  0   0   0  3327    0  ...        0      0
# 1499   0  55315  30228  0    0  0   0   0  3327    0  ...        0      0
#
#       Im_d_d  Rv_d_d  Dv_d_d  E_d_d  Icr_d_d  Ev_d_d  D_d_d  Icrv_d_d
# ...

# %%
model.totals
# Out:
#       Hv     Sv      S  R  Imv  H  Im  Rv    Dv    E  Icr   Ev      D  Icrv
# 0      0    100  99886  0   14  1  10   0     1  213    0  196      0     0
# 1      0    199  99783  0   14  1  10   0     1  217    0  196      0     0
# 2      0    298  99683  0   15  2  10   0     1  216    1  194      0     1
# 3      0    397  99581  0   17  2  11   0     1  217    2  192      0     1
# 4      0    496  99475  0   17  2  12   0     1  223    2  191      0     2
# ...   ..    ...    ... ..  ... ..  ..  ..   ...  ...  ...  ...    ...   ...
# 1495   0  55199  30344  0    0  0   0   0  3327    0    0    0  11551     0
# 1496   0  55232  30311  0    0  0   0   0  3327    0    0    0  11551     0
# 1497   0  55263  30280  0    0  0   0   0  3327    0    0    0  11551     0
# 1498   0  55295  30248  0    0  0   0   0  3327    0    0    0  11551     0
# 1499   0  55315  30228  0    0  0   0   0  3327    0    0    0  11551     0
#
# [1500 rows x 14 columns]

# %%
model.daily
# Out:
#       Hv_d_d  Sv_d_d  S_d_d  R_d_d  Imv_d_d  H_d_d  Im_d_d  Rv_d_d  Dv_d_d  \
# 0          0     100      0      0        4      1       0       0       0
# 1          0     100      0      0        0      0       0       0       0
# 2          0     100      0      0        1      1       0       0       0
# 3          0     100      0      0        2      0       1       0       0
# 4          0     100      0      0        0      0       1       0       0
# ...      ...     ...    ...    ...      ...    ...     ...     ...     ...
# 1495       0     100      0      0        0      0       0       0       0
# 1496       0     100      0      0        0      0       0       0       0
# 1497       0     100      0      0        0      0       0       0       0
# 1498       0     100      0      0        0      0       0       0       0
# 1499       0     100      0      0        0      0       0       0       0
#
#       E_d_d  Icr_d_d  Ev_d_d  D_d_d  Icrv_d_d
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(model.S[False], label='S')
plt.plot(model.S[True], label='Sv')
plt.plot(model.E[False], label='E')
plt.plot(model.E[True], label='Ev')
plt.plot(model.Im[False], label='Im')
plt.plot(model.Im[True], label='Imv')
plt.plot(model.Icr[False], label= 'Icr')
plt.plot(model.Icr[True], label = 'Icrv')
plt.plot(model.R[True] + model.R[False], label='R')
plt.plot(model.H[True] + model.H[False], label='H')
plt.plot(model.D[True] + model.D[False], label='D')
plt.legend(loc=0)
plt.show()
