# %% [markdown]
# # CV19GMData
# Data Management library
# ## Work in progress

# %%
import json
import requests
from requests.auth import HTTPBasicAuth
import pandas as pd
from datetime import datetime

from datetime import timedelta
import numpy as np
from os import path
import matplotlib.pyplot as plt

import sys
from pathlib import Path

from cv19gm.utils.cv19timeutils import timeJStoPy 

import cv19gm.cv19sim as cv19sim

# %%
import cv19gm.data.cv19data as cv19data

# %%
a = cv19data.ImportData(tstate= '13',initdate = datetime(2020,10,19))

# %%
a.import_data()
# Out:
# Importing general data
# Importing Population
# Dlab Endpoint Error
# Importing Population
# Importing Active infected
# Dlab Endpoint Error
# Importing Active Infected by Minciencia
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/urllib3-1.26.15-py3.8.egg/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/urllib3-1.26.15-py3.8.egg/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/urllib3-1.26.15-py3.8.egg/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/urllib3-1.26.15-py3.8.egg/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/urllib3-1.26.15-py3.8.egg/urllib3/connectionpool.py:398, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397     else:
# --> 398         conn.request(method, url, **httplib_request_kw)
#     400 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     401 # legitimately able to close the connection after sending a valid response.
#     402 # With this behaviour, the received response is still readable.
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/urllib3-1.26.15-py3.8.egg/urllib3/connection.py:244, in HTTPConnection.request(self, method, url, body, headers)
#     243     headers["User-Agent"] = _get_default_user_agent()
# --> 244 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/http/client.py:1256, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1255 """Send a complete request to the server."""
# -> 1256 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/http/client.py:1302, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1301     body = _encode(body, 'body')
# -> 1302 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/http/client.py:1251, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1250     raise CannotSendHeader()
# -> 1251 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/http/client.py:1011, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1010 del self._buffer[:]
# -> 1011 self.send(msg)
#    1013 if message_body is not None:
#    1014
#    1015     # create a consistent interface to message_body
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/http/client.py:951, in HTTPConnection.send(self, data)
#     950 if self.auto_open:
# --> 951     self.connect()
#     952 else:
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/urllib3-1.26.15-py3.8.egg/urllib3/connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/urllib3-1.26.15-py3.8.egg/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f372b3fc1c0>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/requests-2.28.1-py3.8.egg/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/urllib3-1.26.15-py3.8.egg/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/urllib3-1.26.15-py3.8.egg/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='192.168.2.223', port=5006): Max retries exceeded with url: /getActiveCasesAllComunas (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f372b3fc1c0>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/cv19gm/data/cv19data.py:187, in ImportData.import_data(self)
#     186 try:
# --> 187     self.imp_infected_active()
#     188 except:
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/cv19gm/data/cv19data.py:490, in ImportData.imp_infected_active(self, tstate, initdate, endpoint, user, password, name)
#     479 # ---------------------- #
#     480 #   Infectados Activos   #
#     481 # ---------------------- #
#    (...)
#     487 #    aux = requests.get('https://api.cv19gm.org/getActiveCasesAllComunas', auth=HTTPBasicAuth(self.user, self.password))
#     488 #    data = pd.DataFrame(aux.json()['data'])
# --> 490 data = pd.DataFrame(request(endpoint).json()['data'])
#     492 if type(tstate) == list:
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/cv19gm/data/cv19data.py:80, in dataretriever.<locals>.request(endpoint)
#      79     else:
# ---> 80         aux = requests.get('http://192.168.2.223:5006/'+endpoint)
#      81 return aux
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/requests-2.28.1-py3.8.egg/requests/api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)
#      70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/requests-2.28.1-py3.8.egg/requests/api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/requests-2.28.1-py3.8.egg/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/requests-2.28.1-py3.8.egg/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/requests-2.28.1-py3.8.egg/requests/adapters.py:565, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     563         raise SSLError(e, request=request)
# --> 565     raise ConnectionError(e, request=request)
#     567 except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='192.168.2.223', port=5006): Max retries exceeded with url: /getActiveCasesAllComunas (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f372b3fc1c0>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /home/samuel/covid19geomodeller/Examples/CV19GMData.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/samuel/covid19geomodeller/Examples/CV19GMData.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> a.import_data()
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/cv19gm/data/cv19data.py:190, in ImportData.import_data(self)
#     188 except:
#     189     print('Dlab Endpoint Error')
# --> 190     self.imp_infected_active_mcyt()
#     191 try:
#     192     self.imp_infected_accumulated()
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/cv19gm/data/cv19data.py:562, in ImportData.imp_infected_active_mcyt(self, tstate, initdate, endpoint, name)
#     560 else:
#     561     I_minciencia_r = aux.loc[aux['Codigo region']==int(tstate)].iloc[:,5:-1]
# --> 562     I_minciencia_r = I_minciencia_r.append(aux.loc[aux['Codigo comuna']==int(tstate)].iloc[:,5:-1])
#     563     I_minciencia_r = I_minciencia_r.sum()
#     566 #self.I_minciencia_r = aux.loc[aux['Codigo region']==int(self.tstate[:2])].iloc[:,5:].sum()
#
# File ~/anaconda3/envs/CV19GM/lib/python3.8/site-packages/pandas-2.0.0rc0-py3.8-linux-x86_64.egg/pandas/core/generic.py:5973, in NDFrame.__getattr__(self, name)
#    5966 if (
#    5967     name not in self._internal_names_set
#    5968     and name not in self._metadata
#    5969     and name not in self._accessors
#    5970     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5971 ):
#    5972     return self[name]
# -> 5973 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
a.I_d_r_dates[-1]
# Out:
# datetime.datetime(2022, 1, 24, 0, 0)

# %%
state = '13'

# %%
data1 = request(endpoint1).json()
data2 = request(endpoint2+state).json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-79a9d6d2d7cc> in <module>
# ----> 1 data1 = request(endpoint1).json()
#       2 data2 = request(endpoint2+state).json()
#
# NameError: name 'request' is not defined

# %%
data1['data'].keys()
# Out:
# dict_keys(['10', '11', '12', '13', '14', '15', '16', '01', '02', '03', '04', '05', '06', '07', '08', '09'])

# %%
data1['data']['13'].keys()
# Out:
# dict_keys(['capacity', 'occupied_covid', 'occupied_non_covid'])

# %%
data2.keys()
# Out:
# dict_keys(['dates', 'camas_ocupadas', 'camas_totales', 'vmi_covid19_confirmados', 'vmi_covid19_sospechosos', 'vmi_ocupados', 'vmi_totales'])

# %%
pd.DataFrame(data2)
# Out:
#                         dates  camas_ocupadas  camas_totales  \
# 0    2020-04-12T04:00:00.000Z          1005.0           1564
# 1    2020-04-13T04:00:00.000Z           991.0           1571
# 2    2020-04-15T04:00:00.000Z          1111.0           1649
# 3    2020-04-16T04:00:00.000Z          1117.0           1646
# 4    2020-04-18T04:00:00.000Z          1076.0           1617
# ..                        ...             ...            ...
# 178  2020-10-26T03:00:00.000Z          1873.0           2328
# 179  2020-10-27T03:00:00.000Z          1920.0           2336
# 180  2020-10-28T03:00:00.000Z          1912.0           2337
# 181  2020-10-29T03:00:00.000Z          1861.0           2337
# 182  2020-10-30T03:00:00.000Z          1899.0           2326
#
#      vmi_covid19_confirmados  vmi_covid19_sospechosos  vmi_ocupados  \
# 0                        156                       22           345
# 1                        169                       27           321
# 2                        156                       20           338
# 3                        157                       15           339
# 4                        187                       15           354
# ..                       ...                      ...           ...
# 178                      288                        8           576
# 179                      289                        9           590
# 180                      293                       12           601
# 181                      285                       13           600
# 182                      274                        9           591
#
#      vmi_totales
# 0            789
# 1            792
# 2            838
# 3            840
# 4            812
# ..           ...
# 178         1304
# 179         1289
# 180         1290
# 181         1290
# 182         1308
#
# [183 rows x 7 columns]

# %%
pd.DataFrame(data1['data']['13'])
# Out:
#      capacity  occupied_covid  occupied_non_covid
# 0         793             198                 298
# 1         808             196                 314
# 2         808             202                 317
# 3         808             181                 340
# 4         818             186                 341
# ..        ...             ...                 ...
# 577      1102             387                 660
# 578      1109             399                 649
# 579      1114             395                 646
# 580      1121             389                 654
# 581      1118             393                 670
#
# [582 rows x 3 columns]

# %% [markdown]
# ## Comunal

# %%
endpoint = 'getBedsAndVentilationByComuna?comuna='

# %%
comuna = '13101'

# %%
data = request(endpoint+comuna).json()

# %%
pd.DataFrame(data)
# Out:
#                         dates  camas_ocupadas  camas_totales  \
# 0    2020-04-12T04:00:00.000Z           220.0            268
# 1    2020-04-13T04:00:00.000Z           229.0            268
# 2    2020-04-15T04:00:00.000Z           232.0            268
# 3    2020-04-16T04:00:00.000Z           220.0            268
# 4    2020-04-18T04:00:00.000Z           229.0            268
# ..                        ...             ...            ...
# 178  2020-10-26T03:00:00.000Z           272.0            294
# 179  2020-10-27T03:00:00.000Z           276.0            302
# 180  2020-10-28T03:00:00.000Z           279.0            302
# 181  2020-10-29T03:00:00.000Z           275.0            302
# 182  2020-10-30T03:00:00.000Z           274.0            302
#
#      vmi_covid19_confirmados  vmi_covid19_sospechosos  vmi_ocupados  \
# 0                         33                        5            83
# 1                         34                        8            81
# 2                         37                        7            88
# 3                         36                        4            81
# 4                         42                        5            91
# ..                       ...                      ...           ...
# 178                       27                        2            83
# 179                       24                        2            82
# 180                       22                        7            87
# 181                       25                        7            97
# 182                       24                        1            87
#
#      vmi_totales
# 0            173
# 1            173
# 2            173
# 3            173
# 4            174
# ..           ...
# 178          215
# 179          215
# 180          215
# 181          215
# 182          215
#
# [183 rows x 7 columns]

# %%
pd.DataFrame(request('getHealthcareCenters').json())
# Out:
#      id_minsal                                      nombre_minsal  id_sochimi  \
# 0       101100    Hospital Regional Dr. Juan Noé Crevanni (Arica)           2
# 1       101213                                   Clínica San José           1
# 2       102100     Hospital Dr. Ernesto Torres Galdames (Iquique)           3
# 3       103100         Hospital Dr. Leonardo Guzmán (Antofagasta)           4
# 4       103101             Hospital Dr. Carlos Cisternas (Calama)           9
# ..         ...                                                ...         ...
# 120     900001                         Clínica Red Salud Rancagua          35
# 121     900004  Hospital Clínico Regional Dr. Guillermo Grant ...          47
# 122     900006                                UPC Padre las Casas         122
# 123     900007                             Hospital Metropolitano         124
# 124     900008                                   Clínica Colonial          86
#
#                        nombre_sochimi                      tipo_recinto  \
# 0      Hospital Regional Dr. Juan Noé  Establecimiento Alta Complejidad
# 1                    Clinica San José                           Clínica
# 2        Hospital regional de Iquique  Establecimiento Alta Complejidad
# 3    Hospital regional de Antofagasta  Establecimiento Alta Complejidad
# 4                 Hospital del Calama  Establecimiento Alta Complejidad
# ..                                ...                               ...
# 120        Clinica Red Salud Rancagua                          SIN DATO
# 121                  Gran Benavente 2  Establecimiento Alta Complejidad
# 122               UPC Padre las Casas                          SIN DATO
# 123            Hospital Metropolitano                          Hospital
# 124                  Clínica Colonial                           Clínica
#
#       tipo_dependencia              servicio_salud  \
# 0    Servicio de Salud                    SS ARICA
# 1              Privado                    SS ARICA
# 2    Servicio de Salud                  SS IQUIQUE
# 3    Servicio de Salud              SS ANTOFAGASTA
# 4    Servicio de Salud              SS ANTOFAGASTA
# ..                 ...                         ...
# 120           SIN DATO  SS LIBERTADOR B. O'HIGGINS
# 121  Servicio de Salud               SS CONCEPCIÓN
# 122           SIN DATO            SS ARAUCANÍA SUR
# 123  Servicio de Salud  SS METROPOLITANO OCCIDENTE
# 124            Privado      SS METROPOLITANO NORTE
#
#                                            seremi region_id  \
# 0                         Servicio de Salud Arica        15
# 1                    SEREMI De Arica y Parinacota        15
# 2                       Servicio de Salud Iquique        01
# 3                   Servicio de Salud Antofagasta        02
# 4                   Servicio de Salud Antofagasta        02
# ..                                            ...       ...
# 120  Servicio de Salud Del Libertador B.O'Higgins        06
# 121                  Servicio de Salud Concepción        08
# 122               Servicio de Salud Araucanía Sur        09
# 123     Servicio de Salud Metropolitano Occidente        13
# 124              SEREMI Metropolitana de Santiago        13
#
#                             region comuna_id           comuna  \
# 0               Arica y Parinacota     15101            Arica
# 1               Arica y Parinacota     15101            Arica
# 2                         Tarapacá     01101          Iquique
# 3                      Antofagasta     02101      Antofagasta
# 4                      Antofagasta     02201           Calama
# ..                             ...       ...              ...
# 120  Lib. Gral. Bernardo O'Higgins     06101         Rancagua
# 121                         Biobío     08101       Concepción
# 122                   La Araucanía     09112  Padre Las Casas
# 123      Metropolitana de Santiago     13123      Providencia
# 124      Metropolitana de Santiago     13107       Huechuraba
#
#     servicio_salud_id
# 0                 151
# 1                 151
# 2                 011
# 3                 021
# 4                 021
# ..                ...
# 120               061
# 121               083
# 122               092
# 123               133
# 124               132
#
# [125 rows x 13 columns]

# %%
pd.DataFrame(request('getBedsAndVentilationByHealthService?health_service=151').json())
# Out:
#                         dates  camas_ocupadas  camas_totales  \
# 0    2020-04-12T04:00:00.000Z             7.0             26
# 1    2020-04-13T04:00:00.000Z             8.0             18
# 2    2020-04-15T04:00:00.000Z             8.0             18
# 3    2020-04-16T04:00:00.000Z            14.0             24
# 4    2020-04-18T04:00:00.000Z             8.0             24
# ..                        ...             ...            ...
# 178  2020-10-26T03:00:00.000Z            81.0            112
# 179  2020-10-27T03:00:00.000Z            82.0            112
# 180  2020-10-28T03:00:00.000Z            73.0            112
# 181  2020-10-29T03:00:00.000Z            72.0            112
# 182  2020-10-30T03:00:00.000Z            56.0            112
#
#      vmi_covid19_confirmados  vmi_covid19_sospechosos  vmi_ocupados  \
# 0                          5                        0             6
# 1                          5                        0             5
# 2                          5                        2             8
# 3                          6                        2             9
# 4                          5                        2             8
# ..                       ...                      ...           ...
# 178                       14                        0            19
# 179                       14                        0            19
# 180                       11                        0            12
# 181                       11                        0            12
# 182                       12                        0            14
#
#      vmi_totales
# 0             20
# 1             15
# 2             15
# 3             15
# 4             15
# ..           ...
# 178           57
# 179           57
# 180           57
# 181           56
# 182           57
#
# [183 rows x 7 columns]

# %%
request('getDetailedBedsAndVentilationByHealthService').json()['data']['101'].keys()
# Out:
# dict_keys(['dates', 'camas_ocupadas_intensivo', 'camas_ocupadas_intermedio', 'camas_totales_intensivo', 'camas_totales_intermedio', 'vmi_covid19_confirmados', 'vmi_covid19_sospechosos', 'vmi_ocupados', 'vmi_totales', 'name'])

# %%
request('getBedsAndVentilationByComuna?comuna=13101').json().keys()
# Out:
# dict_keys(['dates', 'camas_ocupadas', 'camas_totales', 'vmi_covid19_confirmados', 'vmi_covid19_sospechosos', 'vmi_ocupados', 'vmi_totales'])

# %% [markdown]
# # Subreporte

# %%
import matplotlib.dates as mdates

# %%
endpoint = 'getNationalNewCasesUnderreport'

# %%
subreporte = pd.DataFrame(request(endpoint).json())

# %%
dates = pd.DataFrame({'dates':[timeJStoPy(subreporte['date'][i]) for i in range(len(subreporte['date']))]})

# %%
subreporte.keys()
# Out:
# Index(['date', 'mean', 'low', 'high'], dtype='object')

# %%
subreporte = pd.concat([dates,subreporte],axis=1)

# %%
subreporte[[ 'mean', 'low', 'high']]
# Out:
#          mean           low      high
# 0    0.956597  7.902282e-01  0.997992
# 1    0.951143  7.944657e-01  0.996782
# 2    0.944615  7.927647e-01  0.994819
# 3    0.936939  7.925831e-01  0.992439
# 4    0.928019  7.842497e-01  0.989187
# ..        ...           ...       ...
# 590  0.000032  5.000000e-07  0.000374
# 591  0.000038  4.300000e-07  0.000481
# 592  0.000046  3.500000e-07  0.000660
# 593  0.000058  2.600000e-07  0.000908
# 594  0.000075  2.200000e-07  0.001356
#
# [595 rows x 3 columns]

# %%
#4k
plt.rcParams["figure.figsize"] = 38.40, 20.56 #19.20,10.80#8,6
# Small Screen
#plt.rcParams["figure.figsize"] = 19.2, 10.80 #19.20,10.80#8,6
plt.rcParams.update({
    "text.usetex": False,
    "font.family": "sans-serif",
    "font.sans-serif":["Arial"]})

# %%
import matplotlib
# %matplotlib tk

# %%
plt.plot(subreporte['dates'],subreporte['mean'],label = 'mean')
plt.plot(subreporte['dates'],subreporte['low'],label = 'low')
plt.plot(subreporte['dates'],subreporte['high'],label = 'high')
plt.title('Subreporte',size=22)
plt.tick_params(labelsize=18)
plt.legend(loc=0,fontsize=18)
plt.fmt_xdata = mdates.DateFormatter('%d-%m-%Y')
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # Paso a paso

# %%
endpoint = 'https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/output/producto74/paso_a_paso.csv'

# %%
cuarentenas = pd.read_csv(endpoint)

# %%
cuarentenas
# Out:
#      codigo_region   region_residencia  codigo_comuna comuna_residencia  \
# 0               15  Arica y Parinacota          15101             Arica
# 1               15  Arica y Parinacota          15101             Arica
# 2               15  Arica y Parinacota          15102         Camarones
# 3               15  Arica y Parinacota          15202     General Lagos
# 4               15  Arica y Parinacota          15201             Putre
# ..             ...                 ...            ...               ...
# 383             12          Magallanes          12101      Punta Arenas
# 384             12          Magallanes          12103         Río Verde
# 385             12          Magallanes          12104      San Gregorio
# 386             12          Magallanes          12303          Timaukel
# 387             12          Magallanes          12402  Torres del Paine
#
#        zona  2020-07-28  2020-07-29  2020-07-30  2020-07-31  2020-08-01  ...  \
# 0     Rural           3           3           3           3           3  ...
# 1    Urbana           1           1           1           1           1  ...
# 2     Total           3           3           3           3           3  ...
# 3     Total           3           3           3           3           3  ...
# 4     Total           3           3           3           3           3  ...
# ..      ...         ...         ...         ...         ...         ...  ...
# 383   Total           3           3           3           3           3  ...
# 384   Total           3           3           3           3           3  ...
# 385   Total           3           3           3           3           3  ...
# 386   Total           3           3           3           3           3  ...
# 387   Total           3           3           3           3           3  ...
#
#      2021-11-15  2021-11-16  2021-11-17  2021-11-18  2021-11-19  2021-11-20  \
# 0             3           3           3           3           3           3
# 1             3           3           3           3           3           3
# 2             4           4           4           4           4           4
# 3             4           4           4           4           4           4
# 4             4           4           4           4           4           4
# ..          ...         ...         ...         ...         ...         ...
# 383           4           4           4           4           4           4
# 384           4           4           4           4           4           4
# 385           4           4           4           4           4           4
# 386           4           4           4           4           4           4
# 387           4           4           4           4           4           4
#
#      2021-11-21  2021-11-22  2021-11-23  2021-11-24
# 0             3           3           3           3
# 1             3           3           3           3
# 2             4           4           4           4
# 3             4           4           4           4
# 4             4           4           4           4
# ..          ...         ...         ...         ...
# 383           4           4           4           4
# 384           4           4           4           4
# 385           4           4           4           4
# 386           4           4           4           4
# 387           4           4           4           4
#
# [388 rows x 490 columns]

# %%
def timetxttoDatetime(t):
    return datetime.strptime(t,'%Y-%m-%d')

# %%
cuarentenas[cuarentenas['codigo_region']==13]
# Out:
#      codigo_region region_residencia  codigo_comuna    comuna_residencia  \
# 87              13     Metropolitana          13502                Alhué
# 88              13     Metropolitana          13402                 Buin
# 89              13     Metropolitana          13403      Calera de Tango
# 90              13     Metropolitana          13102            Cerrillos
# 91              13     Metropolitana          13103          Cerro Navia
# 92              13     Metropolitana          13301               Colina
# 93              13     Metropolitana          13104             Conchalí
# 94              13     Metropolitana          13503             Curacaví
# 95              13     Metropolitana          13503             Curacaví
# 96              13     Metropolitana          13105            El Bosque
# 97              13     Metropolitana          13602             El Monte
# 98              13     Metropolitana          13106     Estación Central
# 99              13     Metropolitana          13107           Huechuraba
# 100             13     Metropolitana          13108        Independencia
# 101             13     Metropolitana          13603        Isla de Maipo
# 102             13     Metropolitana          13109          La Cisterna
# 103             13     Metropolitana          13110           La Florida
# 104             13     Metropolitana          13111            La Granja
# 105             13     Metropolitana          13112           La Pintana
# 106             13     Metropolitana          13113             La Reina
# 107             13     Metropolitana          13302                Lampa
# 108             13     Metropolitana          13114           Las Condes
# 109             13     Metropolitana          13115         Lo Barnechea
# 110             13     Metropolitana          13116            Lo Espejo
# 111             13     Metropolitana          13117             Lo Prado
# 112             13     Metropolitana          13118                Macul
# 113             13     Metropolitana          13119                Maipú
# 114             13     Metropolitana          13504          María Pinto
# 115             13     Metropolitana          13501            Melipilla
# 116             13     Metropolitana          13501            Melipilla
# 117             13     Metropolitana          13120                Ñuñoa
# 118             13     Metropolitana          13604        Padre Hurtado
# 119             13     Metropolitana          13404                Paine
# 120             13     Metropolitana          13121  Pedro Aguirre Cerda
# 121             13     Metropolitana          13605             Peñaflor
# 122             13     Metropolitana          13122            Peñalolén
# 123             13     Metropolitana          13202               Pirque
# 124             13     Metropolitana          13123          Providencia
# 125             13     Metropolitana          13124             Pudahuel
# 126             13     Metropolitana          13201          Puente Alto
# 127             13     Metropolitana          13125            Quilicura
# 128             13     Metropolitana          13126        Quinta Normal
# 129             13     Metropolitana          13127             Recoleta
# 130             13     Metropolitana          13128                Renca
# 131             13     Metropolitana          13401         San Bernardo
# 132             13     Metropolitana          13129          San Joaquín
# 133             13     Metropolitana          13203    San José de Maipo
# 134             13     Metropolitana          13203    San José de Maipo
# 135             13     Metropolitana          13130           San Miguel
# 136             13     Metropolitana          13505            San Pedro
# 137             13     Metropolitana          13131            San Ramón
# 138             13     Metropolitana          13101             Santiago
# 139             13     Metropolitana          13601            Talagante
# 140             13     Metropolitana          13303              Til Til
# 141             13     Metropolitana          13132             Vitacura
#
#        zona  2020-07-28  2020-07-29  2020-07-30  2020-07-31  2020-08-01  ...  \
# 87    Total           3           3           3           3           3  ...
# 88    Total           1           1           1           1           1  ...
# 89    Total           1           1           1           1           1  ...
# 90    Total           1           1           1           1           1  ...
# 91    Total           1           1           1           1           1  ...
# 92    Total           2           2           2           2           2  ...
# 93    Total           1           1           1           1           1  ...
# 94    Rural           3           3           3           3           3  ...
# 95   Urbana           1           1           1           1           1  ...
# 96    Total           1           1           1           1           1  ...
# 97    Total           1           1           1           1           1  ...
# 98    Total           1           1           1           1           1  ...
# 99    Total           1           1           1           1           1  ...
# 100   Total           1           1           1           1           1  ...
# 101   Total           1           1           1           1           1  ...
# 102   Total           1           1           1           1           1  ...
# 103   Total           1           1           1           1           1  ...
# 104   Total           1           1           1           1           1  ...
# 105   Total           1           1           1           1           1  ...
# 106   Total           2           2           2           2           2  ...
# 107   Total           1           1           1           1           1  ...
# 108   Total           2           2           2           2           2  ...
# 109   Total           2           2           2           2           2  ...
# 110   Total           1           1           1           1           1  ...
# 111   Total           1           1           1           1           1  ...
# 112   Total           1           1           1           1           1  ...
# 113   Total           1           1           1           1           1  ...
# 114   Total           3           3           3           3           2  ...
# 115   Rural           3           3           3           3           3  ...
# 116  Urbana           1           1           1           1           1  ...
# 117   Total           2           2           2           2           2  ...
# 118   Total           1           1           1           1           1  ...
# 119   Total           3           3           3           3           3  ...
# 120   Total           1           1           1           1           1  ...
# 121   Total           1           1           1           1           1  ...
# 122   Total           1           1           1           1           1  ...
# 123   Total           3           3           3           3           3  ...
# 124   Total           1           1           1           1           1  ...
# 125   Total           1           1           1           1           1  ...
# 126   Total           1           1           1           1           1  ...
# 127   Total           1           1           1           1           1  ...
# 128   Total           1           1           1           1           1  ...
# 129   Total           1           1           1           1           1  ...
# 130   Total           1           1           1           1           1  ...
# 131   Total           1           1           1           1           1  ...
# 132   Total           1           1           1           1           1  ...
# 133   Rural           3           3           3           3           3  ...
# 134  Urbana           1           1           1           1           1  ...
# 135   Total           1           1           1           1           1  ...
# 136   Total           3           3           3           3           3  ...
# 137   Total           1           1           1           1           1  ...
# 138   Total           1           1           1           1           1  ...
# 139   Total           1           1           1           1           1  ...
# 140   Total           2           2           2           2           2  ...
# 141   Total           2           2           2           2           2  ...
#
#      2021-11-15  2021-11-16  2021-11-17  2021-11-18  2021-11-19  2021-11-20  \
# 87            3           3           3           3           3           3
# 88            3           3           3           3           3           3
# 89            3           3           3           3           3           3
# 90            3           3           3           3           3           3
# 91            3           3           3           3           3           3
# 92            3           3           3           3           3           3
# 93            3           3           3           3           3           3
# 94            3           3           3           3           3           3
# 95            3           3           3           3           3           3
# 96            3           3           3           3           3           3
# 97            3           3           3           3           3           3
# 98            3           3           3           3           3           3
# 99            3           3           3           3           3           3
# 100           3           3           3           3           3           3
# 101           3           3           3           3           3           3
# 102           3           3           3           3           3           3
# 103           3           3           3           3           3           3
# 104           3           3           3           3           3           3
# 105           3           3           3           3           3           3
# 106           3           3           3           3           3           3
# 107           3           3           3           3           3           3
# 108           3           3           3           3           3           3
# 109           3           3           3           3           3           3
# 110           3           3           3           3           3           3
# 111           3           3           3           3           3           3
# 112           3           3           3           3           3           3
# 113           3           3           3           3           3           3
# 114           3           3           3           3           3           3
# 115           3           3           3           3           3           3
# 116           3           3           3           3           3           3
# 117           3           3           3           3           3           3
# 118           3           3           3           3           3           3
# 119           3           3           3           3           3           3
# 120           3           3           3           3           3           3
# 121           3           3           3           3           3           3
# 122           3           3           3           3           3           3
# 123           3           3           3           3           3           3
# 124           3           3           3           3           3           3
# 125           3           3           3           3           3           3
# 126           3           3           3           3           3           3
# 127           3           3           3           3           3           3
# 128           3           3           3           3           3           3
# 129           3           3           3           3           3           3
# 130           3           3           3           3           3           3
# 131           3           3           3           3           3           3
# 132           3           3           3           3           3           3
# 133           3           3           3           3           3           3
# 134           3           3           3           3           3           3
# 135           3           3           3           3           3           3
# 136           3           3           3           3           3           3
# 137           3           3           3           3           3           3
# 138           3           3           3           3           3           3
# 139           3           3           3           3           3           3
# 140           3           3           3           3           3           3
# 141           3           3           3           3           3           3
#
#      2021-11-21  2021-11-22  2021-11-23  2021-11-24
# 87            3           3           3           3
# 88            3           3           3           3
# 89            3           3           3           3
# 90            3           3           3           3
# 91            3           3           3           3
# 92            3           3           3           3
# 93            3           3           3           3
# 94            3           3           3           3
# 95            3           3           3           3
# 96            3           3           3           3
# 97            3           3           3           3
# 98            3           3           3           3
# 99            3           3           3           3
# 100           3           3           3           3
# 101           3           3           3           3
# 102           3           3           3           3
# 103           3           3           3           3
# 104           3           3           3           3
# 105           3           3           3           3
# 106           3           3           3           3
# 107           3           3           3           3
# 108           3           3           3           3
# 109           3           3           3           3
# 110           3           3           3           3
# 111           3           3           3           3
# 112           3           3           3           3
# 113           3           3           3           3
# 114           3           3           3           3
# 115           3           3           3           3
# 116           3           3           3           3
# 117           3           3           3           3
# 118           3           3           3           3
# 119           3           3           3           3
# 120           3           3           3           3
# 121           3           3           3           3
# 122           3           3           3           3
# 123           3           3           3           3
# 124           3           3           3           3
# 125           3           3           3           3
# 126           3           3           3           3
# 127           3           3           3           3
# 128           3           3           3           3
# 129           3           3           3           3
# 130           3           3           3           3
# 131           3           3           3           3
# 132           3           3           3           3
# 133           3           3           3           3
# 134           3           3           3           3
# 135           3           3           3           3
# 136           3           3           3           3
# 137           3           3           3           3
# 138           3           3           3           3
# 139           3           3           3           3
# 140           3           3           3           3
# 141           3           3           3           3
#
# [55 rows x 490 columns]

# %%
stgo = cuarentenas[cuarentenas['codigo_comuna']==13101]
lascondes = cuarentenas[cuarentenas['codigo_comuna']==13114]

# %%
stgo_q = stgo.filter(regex='2021*').transpose()
lascondes_q = lascondes.filter(regex='2021*').transpose()

# %%
dates = [timetxttoDatetime(stgo_q.axes[0][i]) for i in range(len(stgo_q.axes[0]))]

# %%
fig, axs = plt.subplots(1, 1)
axs.plot(dates,stgo_q,label='stgo')
axs.plot(dates,lascondes_q,label='LasCondes')
axs.fmt_xdata = mdates.DateFormatter('%Y-%m-%d')
axs.legend(loc=0)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # Casos nuevos diarios informe diario

# %%
initdate = datetime(2020,12,1)

# %%
w = 5
endpoint = 'https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/output/producto5/TotalesNacionales.csv'
casosnuevos = pd.read_csv(endpoint)
I_d = casosnuevos[casosnuevos['Fecha']=='Casos nuevos totales'].transpose()
dates = [timetxttoDatetime(I_d.axes[0][i]) for i in range(1,len(I_d.axes[0]))]
I_d = np.array(I_d.iloc[1:][6])
index = np.where(np.array(dates) >= initdate)[0][0]
dates = dates[index:]
I_d = I_d[index:]
weekdays = [date.weekday(dates[i]) for i in range(len(dates))]
I = pd.DataFrame({'dates':dates,'I':I_d,'weekdays':weekdays})
I_week = I.loc[(I['weekdays']>2) | (I['weekdays']==0)] # Sacando martes y miércoles
I_week_ra = I_week['I'].rolling(w).mean()
I_week_lowess = lowess(I_week_ra,list(range(len(I_week_ra))))

# %%
import statsmodels.api as sm
lowess = sm.nonparametric.lowess

z = lowess(I_d,list(range(len(I_d))))
#w = lowess(y, x, frac=1./3)

# %%
plt.plot(dates,I_d,label='data raw')
plt.plot(I_week['dates'],I_week_ra,linestyle = 'dashed',label='weekdays rolling 5 data points')
plt.plot(I_week['dates'][w-1:],I_week_lowess,linestyle = 'dashed',label='weekdays - lowess')
#plt.plot(I_week['dates'],I_week['I'].rolling(10).mean(),linestyle = 'dotted',label='weekdays rolling 10 5 data points')
#plt.plot(I_week['dates'],I_week_lowess,label='Week lowess')
plt.legend(loc=0)

# %%
w = 7
ra_I_d = np.convolve(I_d, np.ones(w), 'valid') / w

# %%
pdRA_I_d = np.array(I['I'].rolling(7).mean())[7:]

# %%
I_week_lowess = lowess(I_week['I'],list(range(len(I_week['I']))))

# %%
plt.plot(dates,I_d,label='data raw')
#plt.plot(dates,z,label='lowess')
#plt.plot(dates[w-1:],ra_I_d,label='rolling average')
#plt.plot(dates[7:],pdRA_I_d+700,label='rolling average pandas')
#plt.plot(dates[7:],np.array(raSam_I_d)+1000,label='rolling average Sam')
plt.plot(I_week['dates'],I_week['I'].rolling(5).mean(),linestyle = 'dashed',label='weekdays rolling 5 data points')
plt.plot(I_week['dates'],I_week['I'].rolling(10).mean(),linestyle = 'dotted',label='weekdays rolling 10 5 data points')
plt.plot(I_week['dates'],I_week_lowess,label='Week lowess')
plt.legend(loc=0)

# %%
type(I_d)
# Out:
# numpy.ndarray

# %% [markdown]
# L = 0.05
# M = 0.05
# W = 0.1
# J = 0.2
# V = 0.2
# S = 0.2
# D = 0.2

# %%
weights = [0.05,0.1,0.2,0.2,0.2,0.2,0.05]*18

# %%
weights = weights[:-2]

# %%
len(weights)
# Out:
# 124

# %%
def rollingmean(data,window=7):
    aux = []
    for i in range(len(data)-window):
        aux.append(np.mean(data[i:window+i]))
    return(aux)

# %%
raSam_I_d = rollingmean(I_d)

# %% [markdown]
# # Deaths deis

# %%
endpoint = 'getDeathsByState?state='
state = '10'

# %%
pd.DataFrame(request(endpoint+state).json())

# %%
# Initialize model from data

# %%
ls cfg
# Out:
# cv19.toml       SEIRDynamic.toml   SEIRHVD_vac.toml   SEIR_v2.toml
# SEIR2.toml      SEIRHVD_SEIR.toml  SEIRInfo.toml      SEIR_v3.toml
# SEIR_data.toml  SEIRHVD.toml       SEIR_metasim.toml
# SEIRData.toml   SEIRHVD_v2.toml    SEIR.toml

# %%
data = cv19data.ImportData(tstate = '13', initdate = datetime(2021,10,22))

# %%
data.import_data_seir()
# Out:
# Importing data for SEIR model
# Importing Population
# Importing Active infected
# updating database
# Importing Accumulated Infected
# updating database
# Importing Daily Infected
# Done

# %%
data.data
# Out:
#      days      dates       I      I_ac     I_d
# 0       0 2021-10-22  6425.0  842440.0  1126.0
# 1       1 2021-10-23     NaN       NaN  1149.0
# 2       2 2021-10-24     NaN       NaN  1179.0
# 3       3 2021-10-25  6663.0  845928.0  1215.0
# 4       4 2021-10-26     NaN       NaN  1250.0
# ..    ...        ...     ...       ...     ...
# 139   139 2022-03-10     NaN       NaN     NaN
# 140   140 2022-03-11     NaN       NaN     NaN
# 141   141 2022-03-12     NaN       NaN     NaN
# 142   142 2022-03-13     NaN       NaN     NaN
# 143   143 2022-03-14     NaN       NaN     NaN
#
# [144 rows x 5 columns]

# %%
sim = cv19sim.CV19SIM(config = 'cfg/SEIR_data.toml', inputdata = data)

# %%
sim.sims[0].I
# Out:
# 6425.0

# %%
sim.solve()

# %%
sim.sims[0].data.dropna().iloc[0]
# Out:
# days                       0
# dates    2021-10-22 00:00:00
# I                       6425
# I_ac                  842440
# I_d                     1126
# Name: 0, dtype: object

# %%
sim.sims[0].results
# Out:
#        t      dates       S     E   E_d     I   I_d       R  R_d  Flux  \
# 0      0 2021-10-22  988575  1914   335  6425  1126    5000    0   0.0
# 1      1 2021-10-23  987324  2700   911  6257   716    5632  399   0.0
# 2      2 2021-10-24  986094  3326  1113  6238   652    6256  540   0.0
# 3      3 2021-10-25  984857  3844  1192  6329   699    6883  596   0.0
# 4      4 2021-10-26  983595  4291  1237  6502   776    7524  625   0.0
# ..   ...        ...     ...   ...   ...   ...   ...     ...  ...   ...
# 495  495 2023-03-01  201635     0     0     0     0  800279    0   0.0
# 496  496 2023-03-02  201635     0     0     0     0  800279    0   0.0
# 497  497 2023-03-03  201635     0     0     0     0  800279    0   0.0
# 498  498 2023-03-04  201635     0     0     0     0  800279    0   0.0
# 499  499 2023-03-05  201635     0     0     0     0  800279    0   0.0
#
#        E_ac     I_ac    R_ac  I_det  I_d_det  I_ac_det  prevalence_total  \
# 0       335   843566       0   6425     1126    843566          0.843566
# 1      1247   844282     399   6257      716    844282          0.844282
# 2      2360   844934     940   6238      652    844934          0.844934
# 3      3552   845633    1536   6329      699    845633          0.845634
# 4      4790   846410    2161   6502      776    846410          0.846411
# ..      ...      ...     ...    ...      ...       ...               ...
# 495  787418  1633049  795113      0        0   1633049          1.633049
# 496  787418  1633049  795113      0        0   1633049          1.633049
# 497  787418  1633049  795113      0        0   1633049          1.633049
# 498  787418  1633049  795113      0        0   1633049          1.633049
# 499  787418  1633049  795113      0        0   1633049          1.633049
#
#      prevalence_susc  prevalence_det
# 0           0.841954        0.841954
# 1           0.842669        0.842669
# 2           0.843320        0.843320
# 3           0.844018        0.844018
# 4           0.844793        0.844793
# ..               ...             ...
# 495         1.629928        1.629928
# 496         1.629928        1.629928
# 497         1.629928        1.629928
# 498         1.629928        1.629928
# 499         1.629928        1.629928
#
# [500 rows x 19 columns]
